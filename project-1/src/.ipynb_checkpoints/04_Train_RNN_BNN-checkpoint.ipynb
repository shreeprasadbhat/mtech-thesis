# %%
# %%capture
# %run 00_Dataset.ipynb
# %run 01_Data_Preparation.ipynb
# %run 03_Model_RNN_BNN.ipynb
# Out:
# 2022-04-28 09:33:01.206423: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.230143: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.230293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.230788: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-28 09:33:01.231633: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.231759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.231941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.578172: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.578382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.578485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-28 09:33:01.578580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1042 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# # Input pipeline

# %%
# prepare data generators using tf.data
train_dataset = (
    tf.data.Dataset.from_tensor_slices((z_train,mu_train))
    #.shuffle(TRAIN_LENGTH, reshuffle_each_iteration=True)
    .batch(BATCH_SIZE, drop_remainder=True)
);

#test_dataset = tf.data.Dataset.from_tensor_slices((z_test,mu_test)).batch(BATCH_SIZE);
val_dataset = (
    tf.data.Dataset.from_tensor_slices((z_val,mu_val))
    .batch(BATCH_SIZE, drop_remainder=True)
);

# %% [markdown]
# # Train

# %%
model = my_model()

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(1e-3), 
    loss = tf.keras.losses.MeanSquaredError(), 
    metrics = tf.keras.metrics.RootMeanSquaredError())

# %%
# Create a callback that saves the model's weights
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    os.path.join(out_dir,'cp.ckpt'), 
    monitor='val_loss', 
    save_weights_only=True, 
    verbose=1, 
    save_best_only=True
    )

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, patience=10, verbose=1,
    mode='auto', min_delta=0.0001, cooldown=0, min_lr=1e-10
)

early_stopping = [
    tf.keras.callbacks.EarlyStopping(
        # Stop training when `val_loss` is no longer improving
        monitor="val_loss",
        # "no longer improving" being defined as "no better than 1e-2 less"
        min_delta=0,
        # "no longer improving" being further defined as "for at least 2 epochs"
        patience=500,
        verbose=1
    )
]

model_history = model.fit(train_dataset,
                          epochs = EPOCHS,
                          validation_data = val_dataset,
                          callbacks = [checkpoint, early_stopping]
                          )
# Out:
# Epoch 1/10000
# 2022-04-28 09:33:04.139098: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8100
# 823/836 [============================>.] - ETA: 0s - loss: 131.9118 - root_mean_squared_error: 11.4853
# Epoch 00001: val_loss improved from inf to 6.66850, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 5s 3ms/step - loss: 130.1012 - root_mean_squared_error: 11.4062 - val_loss: 6.6685 - val_root_mean_squared_error: 2.5823
# Epoch 2/10000
# 833/836 [============================>.] - ETA: 0s - loss: 11.6063 - root_mean_squared_error: 3.4068
# Epoch 00002: val_loss improved from 6.66850 to 6.45114, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 11.6025 - root_mean_squared_error: 3.4062 - val_loss: 6.4511 - val_root_mean_squared_error: 2.5399
# Epoch 3/10000
# 829/836 [============================>.] - ETA: 0s - loss: 11.2913 - root_mean_squared_error: 3.3603
# Epoch 00003: val_loss improved from 6.45114 to 6.33311, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 11.2778 - root_mean_squared_error: 3.3582 - val_loss: 6.3331 - val_root_mean_squared_error: 2.5166
# Epoch 4/10000
# 824/836 [============================>.] - ETA: 0s - loss: 11.9026 - root_mean_squared_error: 3.4500
# Epoch 00004: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 12.0015 - root_mean_squared_error: 3.4643 - val_loss: 6.8687 - val_root_mean_squared_error: 2.6208
# Epoch 5/10000
# 834/836 [============================>.] - ETA: 0s - loss: 11.3536 - root_mean_squared_error: 3.3695
# Epoch 00005: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.3306 - root_mean_squared_error: 3.3661 - val_loss: 7.1054 - val_root_mean_squared_error: 2.6656
# Epoch 6/10000
# 816/836 [============================>.] - ETA: 0s - loss: 11.4578 - root_mean_squared_error: 3.3849
# Epoch 00006: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.4001 - root_mean_squared_error: 3.3764 - val_loss: 6.3365 - val_root_mean_squared_error: 2.5172
# Epoch 7/10000
# 823/836 [============================>.] - ETA: 0s - loss: 11.6265 - root_mean_squared_error: 3.4098
# Epoch 00007: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.5112 - root_mean_squared_error: 3.3928 - val_loss: 6.3414 - val_root_mean_squared_error: 2.5182
# Epoch 8/10000
# 819/836 [============================>.] - ETA: 0s - loss: 11.7029 - root_mean_squared_error: 3.4210
# Epoch 00008: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.6870 - root_mean_squared_error: 3.4186 - val_loss: 6.8953 - val_root_mean_squared_error: 2.6259
# Epoch 9/10000
# 836/836 [==============================] - ETA: 0s - loss: 11.0613 - root_mean_squared_error: 3.3259
# Epoch 00009: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.0613 - root_mean_squared_error: 3.3259 - val_loss: 6.8349 - val_root_mean_squared_error: 2.6144
# Epoch 10/10000
# 836/836 [==============================] - ETA: 0s - loss: 10.7733 - root_mean_squared_error: 3.2823
# Epoch 00010: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 10.7733 - root_mean_squared_error: 3.2823 - val_loss: 6.6460 - val_root_mean_squared_error: 2.5780
# Epoch 11/10000
# 822/836 [============================>.] - ETA: 0s - loss: 11.0978 - root_mean_squared_error: 3.3313
# Epoch 00011: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.1624 - root_mean_squared_error: 3.3410 - val_loss: 7.0098 - val_root_mean_squared_error: 2.6476
# Epoch 12/10000
# 824/836 [============================>.] - ETA: 0s - loss: 11.4144 - root_mean_squared_error: 3.3785
# Epoch 00012: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 11.4011 - root_mean_squared_error: 3.3765 - val_loss: 6.4316 - val_root_mean_squared_error: 2.5361
# Epoch 13/10000
# 824/836 [============================>.] - ETA: 0s - loss: 10.7800 - root_mean_squared_error: 3.2833
# Epoch 00013: val_loss did not improve from 6.33311
# 836/836 [==============================] - 2s 3ms/step - loss: 10.7805 - root_mean_squared_error: 3.2834 - val_loss: 6.7015 - val_root_mean_squared_error: 2.5887
# Epoch 14/10000
# 835/836 [============================>.] - ETA: 0s - loss: 10.8411 - root_mean_squared_error: 3.2926
# Epoch 00014: val_loss improved from 6.33311 to 3.29409, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 10.8511 - root_mean_squared_error: 3.2941 - val_loss: 3.2941 - val_root_mean_squared_error: 1.8150
# Epoch 15/10000
# 836/836 [==============================] - ETA: 0s - loss: 6.5999 - root_mean_squared_error: 2.5690
# Epoch 00015: val_loss improved from 3.29409 to 2.77416, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 6.5999 - root_mean_squared_error: 2.5690 - val_loss: 2.7742 - val_root_mean_squared_error: 1.6656
# Epoch 16/10000
# 834/836 [============================>.] - ETA: 0s - loss: 5.0722 - root_mean_squared_error: 2.2522
# Epoch 00016: val_loss improved from 2.77416 to 0.42734, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 5.0719 - root_mean_squared_error: 2.2521 - val_loss: 0.4273 - val_root_mean_squared_error: 0.6537
# Epoch 17/10000
# 820/836 [============================>.] - ETA: 0s - loss: 5.4784 - root_mean_squared_error: 2.3406
# Epoch 00017: val_loss did not improve from 0.42734
# 836/836 [==============================] - 3s 3ms/step - loss: 5.4104 - root_mean_squared_error: 2.3260 - val_loss: 1.3306 - val_root_mean_squared_error: 1.1535
# Epoch 18/10000
# 822/836 [============================>.] - ETA: 0s - loss: 5.5177 - root_mean_squared_error: 2.3490
# Epoch 00018: val_loss did not improve from 0.42734
# 836/836 [==============================] - 2s 3ms/step - loss: 5.5374 - root_mean_squared_error: 2.3532 - val_loss: 0.8830 - val_root_mean_squared_error: 0.9397
# Epoch 19/10000
# 823/836 [============================>.] - ETA: 0s - loss: 5.0916 - root_mean_squared_error: 2.2565
# Epoch 00019: val_loss did not improve from 0.42734
# 836/836 [==============================] - 2s 3ms/step - loss: 5.1207 - root_mean_squared_error: 2.2629 - val_loss: 0.8709 - val_root_mean_squared_error: 0.9332
# Epoch 20/10000
# 821/836 [============================>.] - ETA: 0s - loss: 4.8777 - root_mean_squared_error: 2.2086
# Epoch 00020: val_loss improved from 0.42734 to 0.32022, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 4.8642 - root_mean_squared_error: 2.2055 - val_loss: 0.3202 - val_root_mean_squared_error: 0.5659
# Epoch 21/10000
# 819/836 [============================>.] - ETA: 0s - loss: 5.4620 - root_mean_squared_error: 2.3371
# Epoch 00021: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 5.4172 - root_mean_squared_error: 2.3275 - val_loss: 0.3259 - val_root_mean_squared_error: 0.5709
# Epoch 22/10000
# 821/836 [============================>.] - ETA: 0s - loss: 5.0835 - root_mean_squared_error: 2.2547
# Epoch 00022: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 5.0378 - root_mean_squared_error: 2.2445 - val_loss: 1.1849 - val_root_mean_squared_error: 1.0885
# Epoch 23/10000
# 829/836 [============================>.] - ETA: 0s - loss: 4.9337 - root_mean_squared_error: 2.2212
# Epoch 00023: val_loss did not improve from 0.32022
# 836/836 [==============================] - 3s 3ms/step - loss: 4.9846 - root_mean_squared_error: 2.2326 - val_loss: 0.4233 - val_root_mean_squared_error: 0.6506
# Epoch 24/10000
# 822/836 [============================>.] - ETA: 0s - loss: 4.5730 - root_mean_squared_error: 2.1385
# Epoch 00024: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.5881 - root_mean_squared_error: 2.1420 - val_loss: 0.5880 - val_root_mean_squared_error: 0.7668
# Epoch 25/10000
# 830/836 [============================>.] - ETA: 0s - loss: 5.0295 - root_mean_squared_error: 2.2426
# Epoch 00025: val_loss did not improve from 0.32022
# 836/836 [==============================] - 3s 3ms/step - loss: 5.0237 - root_mean_squared_error: 2.2414 - val_loss: 0.4465 - val_root_mean_squared_error: 0.6682
# Epoch 26/10000
# 819/836 [============================>.] - ETA: 0s - loss: 4.7358 - root_mean_squared_error: 2.1762
# Epoch 00026: val_loss did not improve from 0.32022
# 836/836 [==============================] - 3s 3ms/step - loss: 4.6993 - root_mean_squared_error: 2.1678 - val_loss: 0.6692 - val_root_mean_squared_error: 0.8181
# Epoch 27/10000
# 823/836 [============================>.] - ETA: 0s - loss: 5.0118 - root_mean_squared_error: 2.2387
# Epoch 00027: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.9856 - root_mean_squared_error: 2.2328 - val_loss: 0.3887 - val_root_mean_squared_error: 0.6235
# Epoch 28/10000
# 818/836 [============================>.] - ETA: 0s - loss: 4.9652 - root_mean_squared_error: 2.2283
# Epoch 00028: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.9510 - root_mean_squared_error: 2.2251 - val_loss: 0.4948 - val_root_mean_squared_error: 0.7034
# Epoch 29/10000
# 831/836 [============================>.] - ETA: 0s - loss: 4.6177 - root_mean_squared_error: 2.1489
# Epoch 00029: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.6057 - root_mean_squared_error: 2.1461 - val_loss: 0.4326 - val_root_mean_squared_error: 0.6577
# Epoch 30/10000
# 834/836 [============================>.] - ETA: 0s - loss: 4.7079 - root_mean_squared_error: 2.1698
# Epoch 00030: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.6982 - root_mean_squared_error: 2.1675 - val_loss: 0.4709 - val_root_mean_squared_error: 0.6862
# Epoch 31/10000
# 834/836 [============================>.] - ETA: 0s - loss: 4.5858 - root_mean_squared_error: 2.1414
# Epoch 00031: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.6085 - root_mean_squared_error: 2.1467 - val_loss: 0.8950 - val_root_mean_squared_error: 0.9461
# Epoch 32/10000
# 826/836 [============================>.] - ETA: 0s - loss: 4.5595 - root_mean_squared_error: 2.1353
# Epoch 00032: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.6201 - root_mean_squared_error: 2.1494 - val_loss: 0.6201 - val_root_mean_squared_error: 0.7875
# Epoch 33/10000
# 835/836 [============================>.] - ETA: 0s - loss: 4.4572 - root_mean_squared_error: 2.1112
# Epoch 00033: val_loss did not improve from 0.32022
# 836/836 [==============================] - 2s 3ms/step - loss: 4.4535 - root_mean_squared_error: 2.1103 - val_loss: 1.3350 - val_root_mean_squared_error: 1.1554
# Epoch 34/10000
# 826/836 [============================>.] - ETA: 0s - loss: 4.5968 - root_mean_squared_error: 2.1440
# Epoch 00034: val_loss improved from 0.32022 to 0.21481, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 4.5762 - root_mean_squared_error: 2.1392 - val_loss: 0.2148 - val_root_mean_squared_error: 0.4635
# Epoch 35/10000
# 821/836 [============================>.] - ETA: 0s - loss: 4.5405 - root_mean_squared_error: 2.1308
# Epoch 00035: val_loss improved from 0.21481 to 0.18689, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 3s 3ms/step - loss: 4.5550 - root_mean_squared_error: 2.1342 - val_loss: 0.1869 - val_root_mean_squared_error: 0.4323
# Epoch 36/10000
# 823/836 [============================>.] - ETA: 0s - loss: 4.1609 - root_mean_squared_error: 2.0398
# Epoch 00036: val_loss did not improve from 0.18689
# 836/836 [==============================] - 2s 3ms/step - loss: 4.1737 - root_mean_squared_error: 2.0430 - val_loss: 0.6829 - val_root_mean_squared_error: 0.8264
# Epoch 37/10000
# 814/836 [============================>.] - ETA: 0s - loss: 4.5230 - root_mean_squared_error: 2.1267
# Epoch 00037: val_loss did not improve from 0.18689
# 836/836 [==============================] - 2s 3ms/step - loss: 4.5462 - root_mean_squared_error: 2.1322 - val_loss: 0.8493 - val_root_mean_squared_error: 0.9216
# Epoch 38/10000
# 821/836 [============================>.] - ETA: 0s - loss: 4.7871 - root_mean_squared_error: 2.1880
# Epoch 00038: val_loss did not improve from 0.18689
# 836/836 [==============================] - 2s 3ms/step - loss: 4.8020 - root_mean_squared_error: 2.1914 - val_loss: 0.5559 - val_root_mean_squared_error: 0.7456
# Epoch 39/10000
# 826/836 [============================>.] - ETA: 0s - loss: 4.4478 - root_mean_squared_error: 2.1090
# Epoch 00039: val_loss did not improve from 0.18689
# 836/836 [==============================] - 2s 3ms/step - loss: 4.4810 - root_mean_squared_error: 2.1168 - val_loss: 0.3549 - val_root_mean_squared_error: 0.5957
# Epoch 40/10000
# 825/836 [============================>.] - ETA: 0s - loss: 4.3280 - root_mean_squared_error: 2.0804
# Epoch 00040: val_loss improved from 0.18689 to 0.18430, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 4.3632 - root_mean_squared_error: 2.0888 - val_loss: 0.1843 - val_root_mean_squared_error: 0.4293
# Epoch 41/10000
# 828/836 [============================>.] - ETA: 0s - loss: 4.7131 - root_mean_squared_error: 2.1710
# Epoch 00041: val_loss did not improve from 0.18430
# 836/836 [==============================] - 2s 2ms/step - loss: 4.6974 - root_mean_squared_error: 2.1673 - val_loss: 0.3477 - val_root_mean_squared_error: 0.5896
# Epoch 42/10000
# 832/836 [============================>.] - ETA: 0s - loss: 4.5332 - root_mean_squared_error: 2.1291
# Epoch 00042: val_loss improved from 0.18430 to 0.17361, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 4.5194 - root_mean_squared_error: 2.1259 - val_loss: 0.1736 - val_root_mean_squared_error: 0.4167
# Epoch 43/10000
# 820/836 [============================>.] - ETA: 0s - loss: 4.5243 - root_mean_squared_error: 2.1270
# Epoch 00043: val_loss improved from 0.17361 to 0.16045, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 2ms/step - loss: 4.5474 - root_mean_squared_error: 2.1325 - val_loss: 0.1605 - val_root_mean_squared_error: 0.4006
# Epoch 44/10000
# 823/836 [============================>.] - ETA: 0s - loss: 4.2154 - root_mean_squared_error: 2.0531
# Epoch 00044: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2474 - root_mean_squared_error: 2.0609 - val_loss: 2.8645 - val_root_mean_squared_error: 1.6925
# Epoch 45/10000
# 834/836 [============================>.] - ETA: 0s - loss: 4.6736 - root_mean_squared_error: 2.1619
# Epoch 00045: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.6724 - root_mean_squared_error: 2.1616 - val_loss: 0.5536 - val_root_mean_squared_error: 0.7440
# Epoch 46/10000
# 831/836 [============================>.] - ETA: 0s - loss: 4.4354 - root_mean_squared_error: 2.1060
# Epoch 00046: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.4521 - root_mean_squared_error: 2.1100 - val_loss: 0.2371 - val_root_mean_squared_error: 0.4869
# Epoch 47/10000
# 813/836 [============================>.] - ETA: 0s - loss: 4.3214 - root_mean_squared_error: 2.0788
# Epoch 00047: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.3839 - root_mean_squared_error: 2.0938 - val_loss: 0.2606 - val_root_mean_squared_error: 0.5105
# Epoch 48/10000
# 829/836 [============================>.] - ETA: 0s - loss: 4.5045 - root_mean_squared_error: 2.1224
# Epoch 00048: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.4931 - root_mean_squared_error: 2.1197 - val_loss: 0.2287 - val_root_mean_squared_error: 0.4783
# Epoch 49/10000
# 835/836 [============================>.] - ETA: 0s - loss: 4.4629 - root_mean_squared_error: 2.1126
# Epoch 00049: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.4671 - root_mean_squared_error: 2.1136 - val_loss: 0.2598 - val_root_mean_squared_error: 0.5097
# Epoch 50/10000
# 827/836 [============================>.] - ETA: 0s - loss: 4.2877 - root_mean_squared_error: 2.0707
# Epoch 00050: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2827 - root_mean_squared_error: 2.0695 - val_loss: 0.4875 - val_root_mean_squared_error: 0.6982
# Epoch 51/10000
# 836/836 [==============================] - ETA: 0s - loss: 4.1220 - root_mean_squared_error: 2.0303
# Epoch 00051: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1220 - root_mean_squared_error: 2.0303 - val_loss: 0.4115 - val_root_mean_squared_error: 0.6415
# Epoch 52/10000
# 836/836 [==============================] - ETA: 0s - loss: 4.3507 - root_mean_squared_error: 2.0858
# Epoch 00052: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.3507 - root_mean_squared_error: 2.0858 - val_loss: 0.2523 - val_root_mean_squared_error: 0.5023
# Epoch 53/10000
# 836/836 [==============================] - ETA: 0s - loss: 4.6083 - root_mean_squared_error: 2.1467
# Epoch 00053: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.6083 - root_mean_squared_error: 2.1467 - val_loss: 0.2527 - val_root_mean_squared_error: 0.5027
# Epoch 54/10000
# 833/836 [============================>.] - ETA: 0s - loss: 4.0929 - root_mean_squared_error: 2.0231
# Epoch 00054: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0828 - root_mean_squared_error: 2.0206 - val_loss: 0.3684 - val_root_mean_squared_error: 0.6069
# Epoch 55/10000
# 815/836 [============================>.] - ETA: 0s - loss: 4.1009 - root_mean_squared_error: 2.0251
# Epoch 00055: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 3ms/step - loss: 4.0751 - root_mean_squared_error: 2.0187 - val_loss: 0.3449 - val_root_mean_squared_error: 0.5873
# Epoch 56/10000
# 828/836 [============================>.] - ETA: 0s - loss: 4.4503 - root_mean_squared_error: 2.1096
# Epoch 00056: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.4228 - root_mean_squared_error: 2.1030 - val_loss: 0.1661 - val_root_mean_squared_error: 0.4076
# Epoch 57/10000
# 830/836 [============================>.] - ETA: 0s - loss: 4.1656 - root_mean_squared_error: 2.0410
# Epoch 00057: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1711 - root_mean_squared_error: 2.0423 - val_loss: 0.2907 - val_root_mean_squared_error: 0.5391
# Epoch 58/10000
# 830/836 [============================>.] - ETA: 0s - loss: 4.5862 - root_mean_squared_error: 2.1415
# Epoch 00058: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.5684 - root_mean_squared_error: 2.1374 - val_loss: 0.2139 - val_root_mean_squared_error: 0.4625
# Epoch 59/10000
# 830/836 [============================>.] - ETA: 0s - loss: 3.9655 - root_mean_squared_error: 1.9913
# Epoch 00059: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 3.9684 - root_mean_squared_error: 1.9921 - val_loss: 0.7728 - val_root_mean_squared_error: 0.8791
# Epoch 60/10000
# 834/836 [============================>.] - ETA: 0s - loss: 4.1669 - root_mean_squared_error: 2.0413
# Epoch 00060: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1632 - root_mean_squared_error: 2.0404 - val_loss: 0.1958 - val_root_mean_squared_error: 0.4425
# Epoch 61/10000
# 824/836 [============================>.] - ETA: 0s - loss: 4.4723 - root_mean_squared_error: 2.1148
# Epoch 00061: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 3ms/step - loss: 4.4962 - root_mean_squared_error: 2.1204 - val_loss: 0.7200 - val_root_mean_squared_error: 0.8485
# Epoch 62/10000
# 833/836 [============================>.] - ETA: 0s - loss: 4.2819 - root_mean_squared_error: 2.0693
# Epoch 00062: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2740 - root_mean_squared_error: 2.0674 - val_loss: 0.1881 - val_root_mean_squared_error: 0.4338
# Epoch 63/10000
# 816/836 [============================>.] - ETA: 0s - loss: 4.1473 - root_mean_squared_error: 2.0365
# Epoch 00063: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1509 - root_mean_squared_error: 2.0374 - val_loss: 0.2903 - val_root_mean_squared_error: 0.5388
# Epoch 64/10000
# 815/836 [============================>.] - ETA: 0s - loss: 4.3495 - root_mean_squared_error: 2.0855
# Epoch 00064: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.3329 - root_mean_squared_error: 2.0816 - val_loss: 0.4278 - val_root_mean_squared_error: 0.6541
# Epoch 65/10000
# 817/836 [============================>.] - ETA: 0s - loss: 4.2517 - root_mean_squared_error: 2.0620
# Epoch 00065: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2120 - root_mean_squared_error: 2.0523 - val_loss: 0.2147 - val_root_mean_squared_error: 0.4633
# Epoch 66/10000
# 815/836 [============================>.] - ETA: 0s - loss: 4.2795 - root_mean_squared_error: 2.0687
# Epoch 00066: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2555 - root_mean_squared_error: 2.0629 - val_loss: 0.2242 - val_root_mean_squared_error: 0.4734
# Epoch 67/10000
# 826/836 [============================>.] - ETA: 0s - loss: 4.3503 - root_mean_squared_error: 2.0857
# Epoch 00067: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 3ms/step - loss: 4.3401 - root_mean_squared_error: 2.0833 - val_loss: 0.3691 - val_root_mean_squared_error: 0.6075
# Epoch 68/10000
# 835/836 [============================>.] - ETA: 0s - loss: 4.2084 - root_mean_squared_error: 2.0514
# Epoch 00068: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 3ms/step - loss: 4.2035 - root_mean_squared_error: 2.0502 - val_loss: 0.2703 - val_root_mean_squared_error: 0.5200
# Epoch 69/10000
# 820/836 [============================>.] - ETA: 0s - loss: 4.2721 - root_mean_squared_error: 2.0669
# Epoch 00069: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 3ms/step - loss: 4.2748 - root_mean_squared_error: 2.0676 - val_loss: 0.6056 - val_root_mean_squared_error: 0.7782
# Epoch 70/10000
# 824/836 [============================>.] - ETA: 0s - loss: 4.1190 - root_mean_squared_error: 2.0295
# Epoch 00070: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 3ms/step - loss: 4.0676 - root_mean_squared_error: 2.0168 - val_loss: 0.2342 - val_root_mean_squared_error: 0.4839
# Epoch 71/10000
# 815/836 [============================>.] - ETA: 0s - loss: 4.0369 - root_mean_squared_error: 2.0092
# Epoch 00071: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0403 - root_mean_squared_error: 2.0101 - val_loss: 0.2452 - val_root_mean_squared_error: 0.4952
# Epoch 72/10000
# 818/836 [============================>.] - ETA: 0s - loss: 4.0741 - root_mean_squared_error: 2.0184
# Epoch 00072: val_loss did not improve from 0.16045
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0646 - root_mean_squared_error: 2.0161 - val_loss: 0.9422 - val_root_mean_squared_error: 0.9706
# Epoch 73/10000
# 824/836 [============================>.] - ETA: 0s - loss: 4.0321 - root_mean_squared_error: 2.0080
# Epoch 00073: val_loss improved from 0.16045 to 0.15228, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 4.0242 - root_mean_squared_error: 2.0060 - val_loss: 0.1523 - val_root_mean_squared_error: 0.3902
# Epoch 74/10000
# 815/836 [============================>.] - ETA: 0s - loss: 4.3266 - root_mean_squared_error: 2.0801
# Epoch 00074: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 4.3328 - root_mean_squared_error: 2.0815 - val_loss: 0.4378 - val_root_mean_squared_error: 0.6616
# Epoch 75/10000
# 829/836 [============================>.] - ETA: 0s - loss: 3.8625 - root_mean_squared_error: 1.9653
# Epoch 00075: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8647 - root_mean_squared_error: 1.9659 - val_loss: 0.1586 - val_root_mean_squared_error: 0.3982
# Epoch 76/10000
# 818/836 [============================>.] - ETA: 0s - loss: 4.3059 - root_mean_squared_error: 2.0751
# Epoch 00076: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 4.3027 - root_mean_squared_error: 2.0743 - val_loss: 0.2977 - val_root_mean_squared_error: 0.5456
# Epoch 77/10000
# 836/836 [==============================] - ETA: 0s - loss: 3.9487 - root_mean_squared_error: 1.9871
# Epoch 00077: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 3.9487 - root_mean_squared_error: 1.9871 - val_loss: 0.1810 - val_root_mean_squared_error: 0.4254
# Epoch 78/10000
# 830/836 [============================>.] - ETA: 0s - loss: 4.4132 - root_mean_squared_error: 2.1008
# Epoch 00078: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 4.4210 - root_mean_squared_error: 2.1026 - val_loss: 0.3316 - val_root_mean_squared_error: 0.5758
# Epoch 79/10000
# 821/836 [============================>.] - ETA: 0s - loss: 4.0912 - root_mean_squared_error: 2.0227
# Epoch 00079: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0952 - root_mean_squared_error: 2.0236 - val_loss: 0.2327 - val_root_mean_squared_error: 0.4824
# Epoch 80/10000
# 822/836 [============================>.] - ETA: 0s - loss: 4.8164 - root_mean_squared_error: 2.1946
# Epoch 00080: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 4.8026 - root_mean_squared_error: 2.1915 - val_loss: 0.3024 - val_root_mean_squared_error: 0.5499
# Epoch 81/10000
# 824/836 [============================>.] - ETA: 0s - loss: 3.7424 - root_mean_squared_error: 1.9345
# Epoch 00081: val_loss did not improve from 0.15228
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7363 - root_mean_squared_error: 1.9329 - val_loss: 0.1649 - val_root_mean_squared_error: 0.4060
# Epoch 82/10000
# 813/836 [============================>.] - ETA: 0s - loss: 4.3374 - root_mean_squared_error: 2.0826
# Epoch 00082: val_loss improved from 0.15228 to 0.12514, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 3ms/step - loss: 4.3220 - root_mean_squared_error: 2.0789 - val_loss: 0.1251 - val_root_mean_squared_error: 0.3537
# Epoch 83/10000
# 813/836 [============================>.] - ETA: 0s - loss: 3.9920 - root_mean_squared_error: 1.9980
# Epoch 00083: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0093 - root_mean_squared_error: 2.0023 - val_loss: 0.2418 - val_root_mean_squared_error: 0.4918
# Epoch 84/10000
# 836/836 [==============================] - ETA: 0s - loss: 3.8772 - root_mean_squared_error: 1.9691
# Epoch 00084: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8772 - root_mean_squared_error: 1.9691 - val_loss: 0.3868 - val_root_mean_squared_error: 0.6219
# Epoch 85/10000
# 818/836 [============================>.] - ETA: 0s - loss: 3.9989 - root_mean_squared_error: 1.9997
# Epoch 00085: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.9641 - root_mean_squared_error: 1.9910 - val_loss: 0.4842 - val_root_mean_squared_error: 0.6958
# Epoch 86/10000
# 829/836 [============================>.] - ETA: 0s - loss: 4.2467 - root_mean_squared_error: 2.0608
# Epoch 00086: val_loss did not improve from 0.12514
# 836/836 [==============================] - 3s 4ms/step - loss: 4.2332 - root_mean_squared_error: 2.0575 - val_loss: 0.2599 - val_root_mean_squared_error: 0.5098
# Epoch 87/10000
# 819/836 [============================>.] - ETA: 0s - loss: 4.2948 - root_mean_squared_error: 2.0724
# Epoch 00087: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 4.2459 - root_mean_squared_error: 2.0605 - val_loss: 0.3251 - val_root_mean_squared_error: 0.5702
# Epoch 88/10000
# 836/836 [==============================] - ETA: 0s - loss: 4.2726 - root_mean_squared_error: 2.0670
# Epoch 00088: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 4.2726 - root_mean_squared_error: 2.0670 - val_loss: 0.2466 - val_root_mean_squared_error: 0.4965
# Epoch 89/10000
# 836/836 [==============================] - ETA: 0s - loss: 3.7328 - root_mean_squared_error: 1.9320
# Epoch 00089: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7328 - root_mean_squared_error: 1.9320 - val_loss: 0.2599 - val_root_mean_squared_error: 0.5098
# Epoch 90/10000
# 833/836 [============================>.] - ETA: 0s - loss: 3.9225 - root_mean_squared_error: 1.9805
# Epoch 00090: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.9159 - root_mean_squared_error: 1.9789 - val_loss: 0.5336 - val_root_mean_squared_error: 0.7305
# Epoch 91/10000
# 836/836 [==============================] - ETA: 0s - loss: 3.7994 - root_mean_squared_error: 1.9492
# Epoch 00091: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7994 - root_mean_squared_error: 1.9492 - val_loss: 0.2604 - val_root_mean_squared_error: 0.5103
# Epoch 92/10000
# 829/836 [============================>.] - ETA: 0s - loss: 3.9942 - root_mean_squared_error: 1.9985
# Epoch 00092: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.9763 - root_mean_squared_error: 1.9941 - val_loss: 0.3177 - val_root_mean_squared_error: 0.5636
# Epoch 93/10000
# 834/836 [============================>.] - ETA: 0s - loss: 3.9588 - root_mean_squared_error: 1.9897
# Epoch 00093: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.9575 - root_mean_squared_error: 1.9894 - val_loss: 0.1976 - val_root_mean_squared_error: 0.4445
# Epoch 94/10000
# 814/836 [============================>.] - ETA: 0s - loss: 4.3100 - root_mean_squared_error: 2.0760
# Epoch 00094: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2535 - root_mean_squared_error: 2.0624 - val_loss: 0.3345 - val_root_mean_squared_error: 0.5784
# Epoch 95/10000
# 822/836 [============================>.] - ETA: 0s - loss: 3.7003 - root_mean_squared_error: 1.9236
# Epoch 00095: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.6898 - root_mean_squared_error: 1.9209 - val_loss: 0.8328 - val_root_mean_squared_error: 0.9126
# Epoch 96/10000
# 829/836 [============================>.] - ETA: 0s - loss: 3.6996 - root_mean_squared_error: 1.9234
# Epoch 00096: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.6890 - root_mean_squared_error: 1.9207 - val_loss: 0.9508 - val_root_mean_squared_error: 0.9751
# Epoch 97/10000
# 835/836 [============================>.] - ETA: 0s - loss: 3.8842 - root_mean_squared_error: 1.9708
# Epoch 00097: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8822 - root_mean_squared_error: 1.9703 - val_loss: 0.2238 - val_root_mean_squared_error: 0.4731
# Epoch 98/10000
# 830/836 [============================>.] - ETA: 0s - loss: 3.7336 - root_mean_squared_error: 1.9323
# Epoch 00098: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7635 - root_mean_squared_error: 1.9400 - val_loss: 0.4293 - val_root_mean_squared_error: 0.6552
# Epoch 99/10000
# 824/836 [============================>.] - ETA: 0s - loss: 4.0698 - root_mean_squared_error: 2.0174
# Epoch 00099: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0630 - root_mean_squared_error: 2.0157 - val_loss: 0.4507 - val_root_mean_squared_error: 0.6713
# Epoch 100/10000
# 831/836 [============================>.] - ETA: 0s - loss: 3.9216 - root_mean_squared_error: 1.9803
# Epoch 00100: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.9104 - root_mean_squared_error: 1.9775 - val_loss: 0.6837 - val_root_mean_squared_error: 0.8269
# Epoch 101/10000
# 817/836 [============================>.] - ETA: 0s - loss: 3.7837 - root_mean_squared_error: 1.9452
# Epoch 00101: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8101 - root_mean_squared_error: 1.9520 - val_loss: 0.1515 - val_root_mean_squared_error: 0.3893
# Epoch 102/10000
# 829/836 [============================>.] - ETA: 0s - loss: 4.1194 - root_mean_squared_error: 2.0296
# Epoch 00102: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1414 - root_mean_squared_error: 2.0350 - val_loss: 0.4216 - val_root_mean_squared_error: 0.6493
# Epoch 103/10000
# 835/836 [============================>.] - ETA: 0s - loss: 3.7721 - root_mean_squared_error: 1.9422
# Epoch 00103: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7685 - root_mean_squared_error: 1.9413 - val_loss: 0.1825 - val_root_mean_squared_error: 0.4272
# Epoch 104/10000
# 835/836 [============================>.] - ETA: 0s - loss: 4.1538 - root_mean_squared_error: 2.0381
# Epoch 00104: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1490 - root_mean_squared_error: 2.0369 - val_loss: 0.2777 - val_root_mean_squared_error: 0.5270
# Epoch 105/10000
# 835/836 [============================>.] - ETA: 0s - loss: 4.0428 - root_mean_squared_error: 2.0107
# Epoch 00105: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.0618 - root_mean_squared_error: 2.0154 - val_loss: 0.4084 - val_root_mean_squared_error: 0.6391
# Epoch 106/10000
# 825/836 [============================>.] - ETA: 0s - loss: 3.8154 - root_mean_squared_error: 1.9533
# Epoch 00106: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8328 - root_mean_squared_error: 1.9578 - val_loss: 0.3876 - val_root_mean_squared_error: 0.6226
# Epoch 107/10000
# 827/836 [============================>.] - ETA: 0s - loss: 3.6666 - root_mean_squared_error: 1.9148
# Epoch 00107: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.6483 - root_mean_squared_error: 1.9100 - val_loss: 0.2452 - val_root_mean_squared_error: 0.4952
# Epoch 108/10000
# 836/836 [==============================] - ETA: 0s - loss: 4.1091 - root_mean_squared_error: 2.0271
# Epoch 00108: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 4.1091 - root_mean_squared_error: 2.0271 - val_loss: 0.3549 - val_root_mean_squared_error: 0.5958
# Epoch 109/10000
# 817/836 [============================>.] - ETA: 0s - loss: 4.1400 - root_mean_squared_error: 2.0347
# Epoch 00109: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 4.1342 - root_mean_squared_error: 2.0333 - val_loss: 0.2406 - val_root_mean_squared_error: 0.4905
# Epoch 110/10000
# 828/836 [============================>.] - ETA: 0s - loss: 3.7973 - root_mean_squared_error: 1.9487
# Epoch 00110: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8756 - root_mean_squared_error: 1.9687 - val_loss: 0.3491 - val_root_mean_squared_error: 0.5908
# Epoch 111/10000
# 832/836 [============================>.] - ETA: 0s - loss: 3.4859 - root_mean_squared_error: 1.8671
# Epoch 00111: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.4846 - root_mean_squared_error: 1.8667 - val_loss: 0.7546 - val_root_mean_squared_error: 0.8687
# Epoch 112/10000
# 819/836 [============================>.] - ETA: 0s - loss: 3.5975 - root_mean_squared_error: 1.8967
# Epoch 00112: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.5862 - root_mean_squared_error: 1.8937 - val_loss: 0.2135 - val_root_mean_squared_error: 0.4620
# Epoch 113/10000
# 828/836 [============================>.] - ETA: 0s - loss: 3.6771 - root_mean_squared_error: 1.9176
# Epoch 00113: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.6804 - root_mean_squared_error: 1.9184 - val_loss: 0.2806 - val_root_mean_squared_error: 0.5297
# Epoch 114/10000
# 824/836 [============================>.] - ETA: 0s - loss: 3.7432 - root_mean_squared_error: 1.9347
# Epoch 00114: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7156 - root_mean_squared_error: 1.9276 - val_loss: 0.3586 - val_root_mean_squared_error: 0.5988
# Epoch 115/10000
# 822/836 [============================>.] - ETA: 0s - loss: 3.7349 - root_mean_squared_error: 1.9326
# Epoch 00115: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7286 - root_mean_squared_error: 1.9309 - val_loss: 0.3366 - val_root_mean_squared_error: 0.5802
# Epoch 116/10000
# 822/836 [============================>.] - ETA: 0s - loss: 4.1248 - root_mean_squared_error: 2.0310
# Epoch 00116: val_loss did not improve from 0.12514
# 836/836 [==============================] - 3s 3ms/step - loss: 4.1221 - root_mean_squared_error: 2.0303 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3710
# Epoch 117/10000
# 827/836 [============================>.] - ETA: 0s - loss: 3.7611 - root_mean_squared_error: 1.9394
# Epoch 00117: val_loss did not improve from 0.12514
# 836/836 [==============================] - 3s 4ms/step - loss: 3.7918 - root_mean_squared_error: 1.9473 - val_loss: 0.2893 - val_root_mean_squared_error: 0.5378
# Epoch 118/10000
# 821/836 [============================>.] - ETA: 0s - loss: 3.8248 - root_mean_squared_error: 1.9557
# Epoch 00118: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8838 - root_mean_squared_error: 1.9707 - val_loss: 0.2086 - val_root_mean_squared_error: 0.4567
# Epoch 119/10000
# 824/836 [============================>.] - ETA: 0s - loss: 3.8561 - root_mean_squared_error: 1.9637
# Epoch 00119: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.8347 - root_mean_squared_error: 1.9582 - val_loss: 0.2159 - val_root_mean_squared_error: 0.4646
# Epoch 120/10000
# 831/836 [============================>.] - ETA: 0s - loss: 3.7142 - root_mean_squared_error: 1.9272
# Epoch 00120: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.7110 - root_mean_squared_error: 1.9264 - val_loss: 0.3609 - val_root_mean_squared_error: 0.6007
# Epoch 121/10000
# 826/836 [============================>.] - ETA: 0s - loss: 3.9218 - root_mean_squared_error: 1.9803
# Epoch 00121: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8976 - root_mean_squared_error: 1.9742 - val_loss: 0.4513 - val_root_mean_squared_error: 0.6718
# Epoch 122/10000
# 827/836 [============================>.] - ETA: 0s - loss: 3.5105 - root_mean_squared_error: 1.8736
# Epoch 00122: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.5043 - root_mean_squared_error: 1.8720 - val_loss: 0.1862 - val_root_mean_squared_error: 0.4315
# Epoch 123/10000
# 827/836 [============================>.] - ETA: 0s - loss: 3.7696 - root_mean_squared_error: 1.9415
# Epoch 00123: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.8090 - root_mean_squared_error: 1.9517 - val_loss: 0.1850 - val_root_mean_squared_error: 0.4301
# Epoch 124/10000
# 824/836 [============================>.] - ETA: 0s - loss: 3.4784 - root_mean_squared_error: 1.8650
# Epoch 00124: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.4743 - root_mean_squared_error: 1.8640 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553
# Epoch 125/10000
# 836/836 [==============================] - ETA: 0s - loss: 3.6299 - root_mean_squared_error: 1.9052
# Epoch 00125: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 3ms/step - loss: 3.6299 - root_mean_squared_error: 1.9052 - val_loss: 0.1889 - val_root_mean_squared_error: 0.4346
# Epoch 126/10000
# 820/836 [============================>.] - ETA: 0s - loss: 3.5980 - root_mean_squared_error: 1.8968
# Epoch 00126: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.5958 - root_mean_squared_error: 1.8963 - val_loss: 0.1304 - val_root_mean_squared_error: 0.3612
# Epoch 127/10000
# 820/836 [============================>.] - ETA: 0s - loss: 3.8425 - root_mean_squared_error: 1.9602
# Epoch 00127: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.8863 - root_mean_squared_error: 1.9714 - val_loss: 0.1369 - val_root_mean_squared_error: 0.3700
# Epoch 128/10000
# 829/836 [============================>.] - ETA: 0s - loss: 3.6097 - root_mean_squared_error: 1.8999
# Epoch 00128: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.5860 - root_mean_squared_error: 1.8937 - val_loss: 0.2730 - val_root_mean_squared_error: 0.5225
# Epoch 129/10000
# 829/836 [============================>.] - ETA: 0s - loss: 3.7396 - root_mean_squared_error: 1.9338
# Epoch 00129: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.7244 - root_mean_squared_error: 1.9299 - val_loss: 0.2128 - val_root_mean_squared_error: 0.4613
# Epoch 130/10000
# 826/836 [============================>.] - ETA: 0s - loss: 3.6944 - root_mean_squared_error: 1.9221
# Epoch 00130: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.6923 - root_mean_squared_error: 1.9215 - val_loss: 0.3883 - val_root_mean_squared_error: 0.6232
# Epoch 131/10000
# 820/836 [============================>.] - ETA: 0s - loss: 3.6159 - root_mean_squared_error: 1.9015
# Epoch 00131: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.6365 - root_mean_squared_error: 1.9070 - val_loss: 0.5475 - val_root_mean_squared_error: 0.7399
# Epoch 132/10000
# 815/836 [============================>.] - ETA: 0s - loss: 3.6408 - root_mean_squared_error: 1.9081
# Epoch 00132: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.6185 - root_mean_squared_error: 1.9022 - val_loss: 0.1571 - val_root_mean_squared_error: 0.3963
# Epoch 133/10000
# 820/836 [============================>.] - ETA: 0s - loss: 3.3192 - root_mean_squared_error: 1.8219
# Epoch 00133: val_loss did not improve from 0.12514
# 836/836 [==============================] - 2s 2ms/step - loss: 3.3142 - root_mean_squared_error: 1.8205 - val_loss: 0.1941 - val_root_mean_squared_error: 0.4406
# Epoch 134/10000
# 815/836 [============================>.] - ETA: 0s - loss: 4.3036 - root_mean_squared_error: 2.0745
# Epoch 00134: val_loss improved from 0.12514 to 0.12364, saving model to ../out/pantheon/cp.ckpt
# 836/836 [==============================] - 2s 2ms/step - loss: 4.2686 - root_mean_squared_error: 2.0660 - val_loss: 0.1236 - val_root_mean_squared_error: 0.3516
# Epoch 135/10000
# 822/836 [============================>.] - ETA: 0s - loss: 3.7423 - root_mean_squared_error: 1.9345
# Epoch 00135: val_loss did not improve from 0.12364
# 836/836 [==============================] - 2s 3ms/step - loss: 3.7354 - root_mean_squared_error: 1.9327 - val_loss: 0.2181 - val_root_mean_squared_error: 0.4670
# Epoch 136/10000
# 833/836 [============================>.] - ETA: 0s - loss: 3.7736 - root_mean_squared_error: 1.9426
# Epoch 00136: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 3ms/step - loss: 3.7663 - root_mean_squared_error: 1.9407 - val_loss: 0.1545 - val_root_mean_squared_error: 0.3930
# Epoch 137/10000
# 823/836 [============================>.] - ETA: 0s - loss: 3.6487 - root_mean_squared_error: 1.9102
# Epoch 00137: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 3ms/step - loss: 3.6559 - root_mean_squared_error: 1.9121 - val_loss: 0.8470 - val_root_mean_squared_error: 0.9203
# Epoch 138/10000
# 823/836 [============================>.] - ETA: 0s - loss: 3.8419 - root_mean_squared_error: 1.9601
# Epoch 00138: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 3ms/step - loss: 3.8306 - root_mean_squared_error: 1.9572 - val_loss: 0.2754 - val_root_mean_squared_error: 0.5248
# Epoch 139/10000
# 820/836 [============================>.] - ETA: 0s - loss: 3.6241 - root_mean_squared_error: 1.9037
# Epoch 00139: val_loss did not improve from 0.12364
# 836/836 [==============================] - 2s 3ms/step - loss: 3.6126 - root_mean_squared_error: 1.9007 - val_loss: 0.1412 - val_root_mean_squared_error: 0.3758
# Epoch 140/10000
# 834/836 [============================>.] - ETA: 0s - loss: 3.7565 - root_mean_squared_error: 1.9382
# Epoch 00140: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 3ms/step - loss: 3.7599 - root_mean_squared_error: 1.9390 - val_loss: 0.3250 - val_root_mean_squared_error: 0.5701
# Epoch 141/10000
# 826/836 [============================>.] - ETA: 0s - loss: 3.3151 - root_mean_squared_error: 1.8208
# Epoch 00141: val_loss did not improve from 0.12364
# 836/836 [==============================] - 2s 3ms/step - loss: 3.3007 - root_mean_squared_error: 1.8168 - val_loss: 0.4259 - val_root_mean_squared_error: 0.6526
# Epoch 142/10000
# 818/836 [============================>.] - ETA: 0s - loss: 3.8131 - root_mean_squared_error: 1.9527
# Epoch 00142: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 3ms/step - loss: 3.7875 - root_mean_squared_error: 1.9462 - val_loss: 0.6006 - val_root_mean_squared_error: 0.7750
# Epoch 143/10000
# 832/836 [============================>.] - ETA: 0s - loss: 3.7890 - root_mean_squared_error: 1.9465
# Epoch 00143: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 4ms/step - loss: 3.7923 - root_mean_squared_error: 1.9474 - val_loss: 0.1403 - val_root_mean_squared_error: 0.3745
# Epoch 144/10000
# 829/836 [============================>.] - ETA: 0s - loss: 3.5630 - root_mean_squared_error: 1.8876
# Epoch 00144: val_loss did not improve from 0.12364
# 836/836 [==============================] - 3s 3ms/step - loss: 3.5759 - root_mean_squared_error: 1.8910 - val_loss: 0.1818 - val_root_mean_squared_error: 0.4264
# Epoch 145/10000
# ...
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0782 - root_mean_squared_error: 0.2797 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2112
# Epoch 2531/10000
# 834/836 [============================>.] - ETA: 0s - loss: 0.0717 - root_mean_squared_error: 0.2678
# Epoch 02531: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0716 - root_mean_squared_error: 0.2675 - val_loss: 0.0468 - val_root_mean_squared_error: 0.2163
# Epoch 2532/10000
# 823/836 [============================>.] - ETA: 0s - loss: 0.0831 - root_mean_squared_error: 0.2882
# Epoch 02532: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0837 - root_mean_squared_error: 0.2893 - val_loss: 0.0407 - val_root_mean_squared_error: 0.2018
# Epoch 2533/10000
# 824/836 [============================>.] - ETA: 0s - loss: 0.0688 - root_mean_squared_error: 0.2623
# Epoch 02533: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0684 - root_mean_squared_error: 0.2615 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1729
# Epoch 2534/10000
# 818/836 [============================>.] - ETA: 0s - loss: 0.0741 - root_mean_squared_error: 0.2722
# Epoch 02534: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0742 - root_mean_squared_error: 0.2724 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1889
# Epoch 2535/10000
# 822/836 [============================>.] - ETA: 0s - loss: 0.0730 - root_mean_squared_error: 0.2703
# Epoch 02535: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0731 - root_mean_squared_error: 0.2704 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2335
# Epoch 2536/10000
# 826/836 [============================>.] - ETA: 0s - loss: 0.0674 - root_mean_squared_error: 0.2595
# Epoch 02536: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0670 - root_mean_squared_error: 0.2589 - val_loss: 0.0717 - val_root_mean_squared_error: 0.2677
# Epoch 2537/10000
# 819/836 [============================>.] - ETA: 0s - loss: 0.0786 - root_mean_squared_error: 0.2804
# Epoch 02537: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0794 - root_mean_squared_error: 0.2818 - val_loss: 0.0251 - val_root_mean_squared_error: 0.1585
# Epoch 2538/10000
# 825/836 [============================>.] - ETA: 0s - loss: 0.0704 - root_mean_squared_error: 0.2654
# Epoch 02538: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0703 - root_mean_squared_error: 0.2651 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 2539/10000
# 831/836 [============================>.] - ETA: 0s - loss: 0.0738 - root_mean_squared_error: 0.2717
# Epoch 02539: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0738 - root_mean_squared_error: 0.2717 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1874
# Epoch 2540/10000
# 816/836 [============================>.] - ETA: 0s - loss: 0.0794 - root_mean_squared_error: 0.2818
# Epoch 02540: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0793 - root_mean_squared_error: 0.2816 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1873
# Epoch 2541/10000
# 817/836 [============================>.] - ETA: 0s - loss: 0.0753 - root_mean_squared_error: 0.2744
# Epoch 02541: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0751 - root_mean_squared_error: 0.2740 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1877
# Epoch 2542/10000
# 819/836 [============================>.] - ETA: 0s - loss: 0.0800 - root_mean_squared_error: 0.2829
# Epoch 02542: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0799 - root_mean_squared_error: 0.2826 - val_loss: 0.0304 - val_root_mean_squared_error: 0.1743
# Epoch 2543/10000
# 819/836 [============================>.] - ETA: 0s - loss: 0.0640 - root_mean_squared_error: 0.2530
# Epoch 02543: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0638 - root_mean_squared_error: 0.2526 - val_loss: 0.0633 - val_root_mean_squared_error: 0.2516
# Epoch 2544/10000
# 820/836 [============================>.] - ETA: 0s - loss: 0.0780 - root_mean_squared_error: 0.2793
# Epoch 02544: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0778 - root_mean_squared_error: 0.2789 - val_loss: 0.0382 - val_root_mean_squared_error: 0.1955
# Epoch 2545/10000
# 816/836 [============================>.] - ETA: 0s - loss: 0.0623 - root_mean_squared_error: 0.2495
# Epoch 02545: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0619 - root_mean_squared_error: 0.2488 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1884
# Epoch 2546/10000
# 824/836 [============================>.] - ETA: 0s - loss: 0.0723 - root_mean_squared_error: 0.2689
# Epoch 02546: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0722 - root_mean_squared_error: 0.2687 - val_loss: 0.0429 - val_root_mean_squared_error: 0.2071
# Epoch 2547/10000
# 821/836 [============================>.] - ETA: 0s - loss: 0.0756 - root_mean_squared_error: 0.2750
# Epoch 02547: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0757 - root_mean_squared_error: 0.2750 - val_loss: 0.0504 - val_root_mean_squared_error: 0.2245
# Epoch 2548/10000
# 818/836 [============================>.] - ETA: 0s - loss: 0.0745 - root_mean_squared_error: 0.2729
# Epoch 02548: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0746 - root_mean_squared_error: 0.2730 - val_loss: 0.0358 - val_root_mean_squared_error: 0.1891
# Epoch 2549/10000
# 820/836 [============================>.] - ETA: 0s - loss: 0.0651 - root_mean_squared_error: 0.2552
# Epoch 02549: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0653 - root_mean_squared_error: 0.2555 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1845
# Epoch 2550/10000
# 822/836 [============================>.] - ETA: 0s - loss: 0.0722 - root_mean_squared_error: 0.2687
# Epoch 02550: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0718 - root_mean_squared_error: 0.2679 - val_loss: 0.0393 - val_root_mean_squared_error: 0.1983
# Epoch 2551/10000
# 827/836 [============================>.] - ETA: 0s - loss: 0.0773 - root_mean_squared_error: 0.2781
# Epoch 02551: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0771 - root_mean_squared_error: 0.2776 - val_loss: 0.0359 - val_root_mean_squared_error: 0.1894
# Epoch 2552/10000
# 821/836 [============================>.] - ETA: 0s - loss: 0.0770 - root_mean_squared_error: 0.2775
# Epoch 02552: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0778 - root_mean_squared_error: 0.2789 - val_loss: 0.0405 - val_root_mean_squared_error: 0.2012
# Epoch 2553/10000
# 822/836 [============================>.] - ETA: 0s - loss: 0.0762 - root_mean_squared_error: 0.2760
# Epoch 02553: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0757 - root_mean_squared_error: 0.2751 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1592
# Epoch 2554/10000
# 825/836 [============================>.] - ETA: 0s - loss: 0.0704 - root_mean_squared_error: 0.2654
# Epoch 02554: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0701 - root_mean_squared_error: 0.2648 - val_loss: 0.0783 - val_root_mean_squared_error: 0.2799
# Epoch 2555/10000
# 824/836 [============================>.] - ETA: 0s - loss: 0.0740 - root_mean_squared_error: 0.2720
# Epoch 02555: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0748 - root_mean_squared_error: 0.2735 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1730
# Epoch 2556/10000
# 826/836 [============================>.] - ETA: 0s - loss: 0.0784 - root_mean_squared_error: 0.2800
# Epoch 02556: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0779 - root_mean_squared_error: 0.2792 - val_loss: 0.0292 - val_root_mean_squared_error: 0.1710
# Epoch 2557/10000
# 819/836 [============================>.] - ETA: 0s - loss: 0.0690 - root_mean_squared_error: 0.2626
# Epoch 02557: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0696 - root_mean_squared_error: 0.2639 - val_loss: 0.0635 - val_root_mean_squared_error: 0.2520
# Epoch 2558/10000
# 819/836 [============================>.] - ETA: 0s - loss: 0.0696 - root_mean_squared_error: 0.2639
# Epoch 02558: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0694 - root_mean_squared_error: 0.2635 - val_loss: 0.0344 - val_root_mean_squared_error: 0.1854
# Epoch 2559/10000
# 816/836 [============================>.] - ETA: 0s - loss: 0.0672 - root_mean_squared_error: 0.2592
# Epoch 02559: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0666 - root_mean_squared_error: 0.2580 - val_loss: 0.0352 - val_root_mean_squared_error: 0.1876
# Epoch 2560/10000
# 818/836 [============================>.] - ETA: 0s - loss: 0.0682 - root_mean_squared_error: 0.2612
# Epoch 02560: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0682 - root_mean_squared_error: 0.2611 - val_loss: 0.0331 - val_root_mean_squared_error: 0.1820
# Epoch 2561/10000
# 819/836 [============================>.] - ETA: 0s - loss: 0.0810 - root_mean_squared_error: 0.2846
# Epoch 02561: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0802 - root_mean_squared_error: 0.2833 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1767
# Epoch 2562/10000
# 832/836 [============================>.] - ETA: 0s - loss: 0.0722 - root_mean_squared_error: 0.2687
# Epoch 02562: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0729 - root_mean_squared_error: 0.2699 - val_loss: 0.0433 - val_root_mean_squared_error: 0.2081
# Epoch 2563/10000
# 821/836 [============================>.] - ETA: 0s - loss: 0.0754 - root_mean_squared_error: 0.2746
# Epoch 02563: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0755 - root_mean_squared_error: 0.2748 - val_loss: 0.0639 - val_root_mean_squared_error: 0.2529
# Epoch 2564/10000
# 836/836 [==============================] - ETA: 0s - loss: 0.0683 - root_mean_squared_error: 0.2613
# Epoch 02564: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0683 - root_mean_squared_error: 0.2613 - val_loss: 0.0656 - val_root_mean_squared_error: 0.2562
# Epoch 2565/10000
# 820/836 [============================>.] - ETA: 0s - loss: 0.0648 - root_mean_squared_error: 0.2546
# Epoch 02565: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0642 - root_mean_squared_error: 0.2534 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1712
# Epoch 2566/10000
# 820/836 [============================>.] - ETA: 0s - loss: 0.0723 - root_mean_squared_error: 0.2689
# Epoch 02566: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0720 - root_mean_squared_error: 0.2683 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1846
# Epoch 2567/10000
# 836/836 [==============================] - ETA: 0s - loss: 0.0738 - root_mean_squared_error: 0.2717
# Epoch 02567: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0738 - root_mean_squared_error: 0.2717 - val_loss: 0.0366 - val_root_mean_squared_error: 0.1912
# Epoch 2568/10000
# 832/836 [============================>.] - ETA: 0s - loss: 0.0780 - root_mean_squared_error: 0.2793
# Epoch 02568: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0780 - root_mean_squared_error: 0.2792 - val_loss: 0.0278 - val_root_mean_squared_error: 0.1667
# Epoch 2569/10000
# 831/836 [============================>.] - ETA: 0s - loss: 0.0774 - root_mean_squared_error: 0.2783
# Epoch 02569: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0776 - root_mean_squared_error: 0.2785 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1777
# Epoch 2570/10000
# 834/836 [============================>.] - ETA: 0s - loss: 0.0687 - root_mean_squared_error: 0.2622
# Epoch 02570: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0687 - root_mean_squared_error: 0.2621 - val_loss: 0.0309 - val_root_mean_squared_error: 0.1758
# Epoch 2571/10000
# 818/836 [============================>.] - ETA: 0s - loss: 0.0765 - root_mean_squared_error: 0.2766
# Epoch 02571: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0765 - root_mean_squared_error: 0.2766 - val_loss: 0.0303 - val_root_mean_squared_error: 0.1741
# Epoch 2572/10000
# 816/836 [============================>.] - ETA: 0s - loss: 0.0741 - root_mean_squared_error: 0.2722
# Epoch 02572: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0741 - root_mean_squared_error: 0.2722 - val_loss: 0.0431 - val_root_mean_squared_error: 0.2077
# Epoch 2573/10000
# 816/836 [============================>.] - ETA: 0s - loss: 0.0734 - root_mean_squared_error: 0.2710
# Epoch 02573: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0747 - root_mean_squared_error: 0.2732 - val_loss: 0.0295 - val_root_mean_squared_error: 0.1718
# Epoch 2574/10000
# 834/836 [============================>.] - ETA: 0s - loss: 0.0698 - root_mean_squared_error: 0.2642
# Epoch 02574: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0697 - root_mean_squared_error: 0.2640 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1806
# Epoch 2575/10000
# 825/836 [============================>.] - ETA: 0s - loss: 0.0742 - root_mean_squared_error: 0.2724
# Epoch 02575: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0743 - root_mean_squared_error: 0.2726 - val_loss: 0.0356 - val_root_mean_squared_error: 0.1887
# Epoch 2576/10000
# 828/836 [============================>.] - ETA: 0s - loss: 0.0700 - root_mean_squared_error: 0.2646
# Epoch 02576: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0709 - root_mean_squared_error: 0.2663 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2494
# Epoch 2577/10000
# 818/836 [============================>.] - ETA: 0s - loss: 0.0694 - root_mean_squared_error: 0.2634
# Epoch 02577: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0693 - root_mean_squared_error: 0.2633 - val_loss: 0.0413 - val_root_mean_squared_error: 0.2032
# Epoch 2578/10000
# 821/836 [============================>.] - ETA: 0s - loss: 0.0823 - root_mean_squared_error: 0.2869
# Epoch 02578: val_loss did not improve from 0.02261
# 836/836 [==============================] - 2s 3ms/step - loss: 0.0823 - root_mean_squared_error: 0.2870 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1821
# Epoch 02578: early stopping

# %%
# load the best weights
model.load_weights(os.path.join(out_dir, 'cp.ckpt'))

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(1, 4, 1)]               0
#
#  lstm_4 (LSTM)               (1, 4, 100)               40800
#
#  dropout_4 (Dropout)         (1, 4, 100)               0
#
#  lstm_5 (LSTM)               (1, 100)                  80400
#
#  dropout_5 (Dropout)         (1, 100)                  0
#
#  dense_2 (Dense)             (1, 1)                    101
#
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(np.arange(20,200,), model_history.history['loss'][20:200], '-', label='train_loss')
#plt.plot(np.arange(0,epochs,1), model_history.history['val_loss'], '--', label='val_loss', )
plt.xlabel('epochs')
plt.ylabel('MeanSquaredLoss')
plt.title('epoch vs loss')
plt.legend()
plt.show()

# %%
# plot epoch vs loss, epoch vs RMSE
plt.figure(figsize=(15,5))

epochs = len(model_history.history['loss'])

plt.subplot(1,2,1)
plt.plot(np.arange(0,epochs,1), model_history.history['loss'], '-', label='train_loss')
#plt.plot(np.arange(0,epochs,1), model_history.history['val_loss'], '--', label='val_loss', )
plt.xlabel('epochs')
plt.ylabel('MeanSquaredLoss')
plt.title('epoch vs loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(np.arange(0,epochs,1), model_history.history['root_mean_squared_error'], '-', label='train_rmse')
#plt.plot(np.arange(0,epochs,1), model_history.history['val_root_mean_squared_error'], '--', label='val_rmse')
plt.xlabel('epochs')
plt.ylabel('RMSE')
plt.title('epoch vs RMSE')
plt.legend()
plt.savefig(os.path.join(out_dir,'05_epoch_vs_loss.png'))
plt.show()

# %%
#model.evaluate(test_dataset)

# %% [markdown]
# # Sample Reconstruction

# %%
# Reconstruct 
z_reconstruct = np.linspace(0,8.5,100)
z_reconstruct = np.expand_dims(strided_app(z_reconstruct, 4, 4), axis=-1)

# %%
z_reconstruct = z_reconstruct[:20]

# %%
mu_reconstruct = model.predict(z_reconstruct, batch_size=BATCH_SIZE)

# %%
BATCH_SIZE
# Out:
# 1

# %%
# plot reconstructed z vs mu
plt.plot(z_reconstruct.flatten(), mu_reconstruct.flatten());
plt.xlabel('redshift(z)')
plt.ylabel('distance modulus(mu)')
plt.title('Distance modulus vs redshift')
plt.savefig(os.path.join(out_dir,'06_sample_reconstruction.png'))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13123/987127950.py in <module>
#       1 # plot reconstructed z vs mu
# ----> 2 plt.plot(z_reconstruct.flatten(), mu_reconstruct.flatten());
#       3 plt.xlabel('redshift(z)')
#       4 plt.ylabel('distance modulus(mu)')
#       5 plt.title('Distance modulus vs redshift')
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (80,) and (20,)

# %% [markdown]
# # Sample Reconstruction with uncertainity

# %%
model_u = model_uncertainity()

# %%
model_u.load_weights(os.path.join(out_dir,'cp.ckpt'))

# %%
model_u.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss=tf.keras.losses.MeanSquaredError(), metrics=tf.keras.metrics.RootMeanSquaredError())

# %%
mu_reconstruct_uncertainity = []
n = 1000
for i in range(n):
    mu_reconstruct_uncertainity.append(model_u.predict(z_reconstruct, batch_size=BATCH_SIZE).flatten())

mu_reconstruct_uncertainity = np.array(mu_reconstruct_uncertainity)
mean = np.mean(mu_reconstruct_uncertainity, axis=0)
std_dev = np.std(mu_reconstruct_uncertainity, axis=0)

# %%
plt.fill_between(z_reconstruct.flatten(), mean-2*std_dev, mean+2*std_dev,label='Reconstruction in 2 sigma')
plt.fill_between(z_reconstruct.flatten(), mean-1*std_dev, mean+1*std_dev,label='Reconstruction in 1 sigma')

plt.plot(z_reconstruct.flatten(), mean, label='Reconstruction')
plt.errorbar(z, mu, yerr=mu_err, fmt='.r', label=dataset+' Sample');
plt.xlabel('redshift(z)')
plt.ylabel('distance modulus(mu)')
plt.title('The reconstruction of distance moduli from '+dataset+' data ')
plt.legend()
plt.show()

plt.savefig(os.path.join(out_dir,'07_sample_reconstruction_with_uncertainity.png'))
