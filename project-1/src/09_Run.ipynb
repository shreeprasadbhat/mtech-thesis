# %%
#%run 01_Data_Preparation.ipynb
#%run 02_Model_GuassianProcess.ipynb
#%run 03_Model_RNN_BNN.ipynb
# %run 04_Train_RNN_BNN.ipynb
# %run 05_Mu_Reconstruction.ipynb
# %run 06_Test_Redshift_Dependence.ipynb
# %run 07_Recaliberate_DistanceModulus.ipynb
# %run 08_Estimate_omegaM_and_omegaL.ipynb
# Out:
# 2022-05-23 13:15:36.306749: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2022-05-23 13:15:36.306790: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: spk
# 2022-05-23 13:15:36.306796: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: spk
# 2022-05-23 13:15:36.306898: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.129.6
# 2022-05-23 13:15:36.306917: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.103.1
# 2022-05-23 13:15:36.306922: E tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 470.103.1 does not match DSO version 470.129.6 -- cannot find working devices in this configuration
# 2022-05-23 13:15:36.307122: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 1.0557 - root_mean_squared_error: 1.0275
# Epoch 00001: val_loss improved from inf to 0.89663, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 3s 90ms/step - loss: 1.0307 - root_mean_squared_error: 1.0152 - val_loss: 0.8966 - val_root_mean_squared_error: 0.9469
# Epoch 2/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.9293 - root_mean_squared_error: 0.9640
# Epoch 00002: val_loss improved from 0.89663 to 0.78891, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9293 - root_mean_squared_error: 0.9640 - val_loss: 0.7889 - val_root_mean_squared_error: 0.8882
# Epoch 3/1000
# 7/8 [=========================>....] - ETA: 0s - loss: 0.8165 - root_mean_squared_error: 0.9036
# Epoch 00003: val_loss improved from 0.78891 to 0.68789, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7989 - root_mean_squared_error: 0.8938 - val_loss: 0.6879 - val_root_mean_squared_error: 0.8294
# Epoch 4/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.7065 - root_mean_squared_error: 0.8405
# Epoch 00004: val_loss improved from 0.68789 to 0.58995, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7065 - root_mean_squared_error: 0.8405 - val_loss: 0.5900 - val_root_mean_squared_error: 0.7681
# Epoch 5/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.5141 - root_mean_squared_error: 0.7170
# Epoch 00005: val_loss improved from 0.58995 to 0.52601, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6163 - root_mean_squared_error: 0.7850 - val_loss: 0.5260 - val_root_mean_squared_error: 0.7253
# Epoch 6/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.4440 - root_mean_squared_error: 0.6663
# Epoch 00006: val_loss improved from 0.52601 to 0.48332, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5510 - root_mean_squared_error: 0.7423 - val_loss: 0.4833 - val_root_mean_squared_error: 0.6952
# Epoch 7/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.4152 - root_mean_squared_error: 0.6443
# Epoch 00007: val_loss improved from 0.48332 to 0.43090, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5079 - root_mean_squared_error: 0.7127 - val_loss: 0.4309 - val_root_mean_squared_error: 0.6564
# Epoch 8/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.3745 - root_mean_squared_error: 0.6120
# Epoch 00008: val_loss improved from 0.43090 to 0.38671, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4517 - root_mean_squared_error: 0.6721 - val_loss: 0.3867 - val_root_mean_squared_error: 0.6219
# Epoch 9/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.3510 - root_mean_squared_error: 0.5924
# Epoch 00009: val_loss improved from 0.38671 to 0.35313, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4080 - root_mean_squared_error: 0.6388 - val_loss: 0.3531 - val_root_mean_squared_error: 0.5942
# Epoch 10/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.3128 - root_mean_squared_error: 0.5592
# Epoch 00010: val_loss improved from 0.35313 to 0.32349, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3678 - root_mean_squared_error: 0.6065 - val_loss: 0.3235 - val_root_mean_squared_error: 0.5688
# Epoch 11/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.2933 - root_mean_squared_error: 0.5415
# Epoch 00011: val_loss improved from 0.32349 to 0.29451, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3368 - root_mean_squared_error: 0.5803 - val_loss: 0.2945 - val_root_mean_squared_error: 0.5427
# Epoch 12/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.2694 - root_mean_squared_error: 0.5190
# Epoch 00012: val_loss improved from 0.29451 to 0.26926, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3126 - root_mean_squared_error: 0.5591 - val_loss: 0.2693 - val_root_mean_squared_error: 0.5189
# Epoch 13/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.2459 - root_mean_squared_error: 0.4959
# Epoch 00013: val_loss improved from 0.26926 to 0.24375, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2862 - root_mean_squared_error: 0.5350 - val_loss: 0.2437 - val_root_mean_squared_error: 0.4937
# Epoch 14/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.2245 - root_mean_squared_error: 0.4738
# Epoch 00014: val_loss improved from 0.24375 to 0.21575, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2613 - root_mean_squared_error: 0.5111 - val_loss: 0.2158 - val_root_mean_squared_error: 0.4645
# Epoch 15/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.2032 - root_mean_squared_error: 0.4508
# Epoch 00015: val_loss improved from 0.21575 to 0.19341, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.2314 - root_mean_squared_error: 0.4810 - val_loss: 0.1934 - val_root_mean_squared_error: 0.4398
# Epoch 16/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1851 - root_mean_squared_error: 0.4302
# Epoch 00016: val_loss improved from 0.19341 to 0.16613, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2040 - root_mean_squared_error: 0.4517 - val_loss: 0.1661 - val_root_mean_squared_error: 0.4076
# Epoch 17/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1635 - root_mean_squared_error: 0.4044
# Epoch 00017: val_loss improved from 0.16613 to 0.14923, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1795 - root_mean_squared_error: 0.4237 - val_loss: 0.1492 - val_root_mean_squared_error: 0.3863
# Epoch 18/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1434 - root_mean_squared_error: 0.3787
# Epoch 00018: val_loss improved from 0.14923 to 0.13908, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1587 - root_mean_squared_error: 0.3984 - val_loss: 0.1391 - val_root_mean_squared_error: 0.3729
# Epoch 19/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1400 - root_mean_squared_error: 0.3741
# Epoch 00019: val_loss improved from 0.13908 to 0.12942, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1507 - root_mean_squared_error: 0.3882 - val_loss: 0.1294 - val_root_mean_squared_error: 0.3598
# Epoch 20/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1371 - root_mean_squared_error: 0.3703
# Epoch 00020: val_loss improved from 0.12942 to 0.11872, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1414 - root_mean_squared_error: 0.3760 - val_loss: 0.1187 - val_root_mean_squared_error: 0.3446
# Epoch 21/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1268 - root_mean_squared_error: 0.3561
# Epoch 00021: val_loss improved from 0.11872 to 0.11659, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1342 - root_mean_squared_error: 0.3663 - val_loss: 0.1166 - val_root_mean_squared_error: 0.3415
# Epoch 22/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1260 - root_mean_squared_error: 0.3550
# Epoch 00022: val_loss improved from 0.11659 to 0.10539, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1294 - root_mean_squared_error: 0.3597 - val_loss: 0.1054 - val_root_mean_squared_error: 0.3246
# Epoch 23/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1233 - root_mean_squared_error: 0.3511
# Epoch 00023: val_loss improved from 0.10539 to 0.09860, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1213 - root_mean_squared_error: 0.3483 - val_loss: 0.0986 - val_root_mean_squared_error: 0.3140
# Epoch 24/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1045 - root_mean_squared_error: 0.3233
# Epoch 00024: val_loss improved from 0.09860 to 0.09514, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1190 - root_mean_squared_error: 0.3450 - val_loss: 0.0951 - val_root_mean_squared_error: 0.3084
# Epoch 25/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1175 - root_mean_squared_error: 0.3428
# Epoch 00025: val_loss improved from 0.09514 to 0.08819, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.1110 - root_mean_squared_error: 0.3332 - val_loss: 0.0882 - val_root_mean_squared_error: 0.2970
# Epoch 26/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0953 - root_mean_squared_error: 0.3087
# Epoch 00026: val_loss did not improve from 0.08819
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1055 - root_mean_squared_error: 0.3248 - val_loss: 0.0884 - val_root_mean_squared_error: 0.2974
# Epoch 27/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.1005 - root_mean_squared_error: 0.3170
# Epoch 00027: val_loss improved from 0.08819 to 0.07984, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1021 - root_mean_squared_error: 0.3195 - val_loss: 0.0798 - val_root_mean_squared_error: 0.2826
# Epoch 28/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0968 - root_mean_squared_error: 0.3110
# Epoch 00028: val_loss improved from 0.07984 to 0.07615, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0925 - root_mean_squared_error: 0.3042 - val_loss: 0.0761 - val_root_mean_squared_error: 0.2759
# Epoch 29/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0854 - root_mean_squared_error: 0.2922
# Epoch 00029: val_loss improved from 0.07615 to 0.07208, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0944 - root_mean_squared_error: 0.3073 - val_loss: 0.0721 - val_root_mean_squared_error: 0.2685
# Epoch 30/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0844 - root_mean_squared_error: 0.2906
# Epoch 00030: val_loss improved from 0.07208 to 0.07125, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0867 - root_mean_squared_error: 0.2944 - val_loss: 0.0713 - val_root_mean_squared_error: 0.2669
# Epoch 31/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0861 - root_mean_squared_error: 0.2934
# Epoch 00031: val_loss improved from 0.07125 to 0.06708, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0871 - root_mean_squared_error: 0.2951 - val_loss: 0.0671 - val_root_mean_squared_error: 0.2590
# Epoch 32/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0805 - root_mean_squared_error: 0.2837
# Epoch 00032: val_loss improved from 0.06708 to 0.06388, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0816 - root_mean_squared_error: 0.2857 - val_loss: 0.0639 - val_root_mean_squared_error: 0.2527
# Epoch 33/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0773 - root_mean_squared_error: 0.2781
# Epoch 00033: val_loss improved from 0.06388 to 0.06221, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0786 - root_mean_squared_error: 0.2804 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2494
# Epoch 34/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0713 - root_mean_squared_error: 0.2670
# Epoch 00034: val_loss improved from 0.06221 to 0.05838, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0797 - root_mean_squared_error: 0.2824 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2416
# Epoch 35/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0794 - root_mean_squared_error: 0.2817
# Epoch 00035: val_loss improved from 0.05838 to 0.05767, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0773 - root_mean_squared_error: 0.2780 - val_loss: 0.0577 - val_root_mean_squared_error: 0.2402
# Epoch 36/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0776 - root_mean_squared_error: 0.2786
# Epoch 00036: val_loss improved from 0.05767 to 0.05534, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0734 - root_mean_squared_error: 0.2710 - val_loss: 0.0553 - val_root_mean_squared_error: 0.2353
# Epoch 37/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0846 - root_mean_squared_error: 0.2909
# Epoch 00037: val_loss improved from 0.05534 to 0.05102, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0706 - root_mean_squared_error: 0.2657 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2259
# Epoch 38/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0677 - root_mean_squared_error: 0.2601
# Epoch 00038: val_loss did not improve from 0.05102
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0675 - root_mean_squared_error: 0.2598 - val_loss: 0.0566 - val_root_mean_squared_error: 0.2378
# Epoch 39/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0729 - root_mean_squared_error: 0.2701
# Epoch 00039: val_loss improved from 0.05102 to 0.04789, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0698 - root_mean_squared_error: 0.2641 - val_loss: 0.0479 - val_root_mean_squared_error: 0.2188
# Epoch 40/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0666 - root_mean_squared_error: 0.2580
# Epoch 00040: val_loss improved from 0.04789 to 0.04758, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0613 - root_mean_squared_error: 0.2475 - val_loss: 0.0476 - val_root_mean_squared_error: 0.2181
# Epoch 41/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0559 - root_mean_squared_error: 0.2364
# Epoch 00041: val_loss improved from 0.04758 to 0.04363, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0609 - root_mean_squared_error: 0.2467 - val_loss: 0.0436 - val_root_mean_squared_error: 0.2089
# Epoch 42/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0569 - root_mean_squared_error: 0.2386
# Epoch 00042: val_loss did not improve from 0.04363
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0588 - root_mean_squared_error: 0.2425 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2093
# Epoch 43/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0672 - root_mean_squared_error: 0.2592
# Epoch 00043: val_loss did not improve from 0.04363
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0640 - root_mean_squared_error: 0.2531 - val_loss: 0.0453 - val_root_mean_squared_error: 0.2128
# Epoch 44/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0566 - root_mean_squared_error: 0.2378
# Epoch 00044: val_loss improved from 0.04363 to 0.03882, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0553 - root_mean_squared_error: 0.2352 - val_loss: 0.0388 - val_root_mean_squared_error: 0.1970
# Epoch 45/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0621 - root_mean_squared_error: 0.2493
# Epoch 00045: val_loss did not improve from 0.03882
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305 - val_loss: 0.0389 - val_root_mean_squared_error: 0.1973
# Epoch 46/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0560 - root_mean_squared_error: 0.2367
# Epoch 00046: val_loss improved from 0.03882 to 0.03695, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0531 - root_mean_squared_error: 0.2305 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1922
# Epoch 47/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0569 - root_mean_squared_error: 0.2386
# Epoch 00047: val_loss improved from 0.03695 to 0.03642, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0481 - root_mean_squared_error: 0.2194 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1908
# Epoch 48/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0525 - root_mean_squared_error: 0.2291
# Epoch 00048: val_loss improved from 0.03642 to 0.03464, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0468 - root_mean_squared_error: 0.2163 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1861
# Epoch 49/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0557 - root_mean_squared_error: 0.2361
# Epoch 00049: val_loss improved from 0.03464 to 0.03253, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0467 - root_mean_squared_error: 0.2160 - val_loss: 0.0325 - val_root_mean_squared_error: 0.1804
# Epoch 50/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0645 - root_mean_squared_error: 0.2539
# Epoch 00050: val_loss did not improve from 0.03253
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0465 - root_mean_squared_error: 0.2156 - val_loss: 0.0329 - val_root_mean_squared_error: 0.1814
# Epoch 51/1000
# 8/8 [==============================] - ETA: 0s - loss: 0.0429 - root_mean_squared_error: 0.2072
# Epoch 00051: val_loss improved from 0.03253 to 0.03047, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0429 - root_mean_squared_error: 0.2072 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1745
# Epoch 52/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0472 - root_mean_squared_error: 0.2173
# Epoch 00052: val_loss did not improve from 0.03047
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0416 - root_mean_squared_error: 0.2040 - val_loss: 0.0316 - val_root_mean_squared_error: 0.1778
# Epoch 53/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0487 - root_mean_squared_error: 0.2207
# Epoch 00053: val_loss improved from 0.03047 to 0.02854, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0407 - root_mean_squared_error: 0.2017 - val_loss: 0.0285 - val_root_mean_squared_error: 0.1689
# Epoch 54/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0490 - root_mean_squared_error: 0.2215
# Epoch 00054: val_loss did not improve from 0.02854
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0430 - root_mean_squared_error: 0.2073 - val_loss: 0.0293 - val_root_mean_squared_error: 0.1711
# Epoch 55/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0681 - root_mean_squared_error: 0.2609
# Epoch 00055: val_loss improved from 0.02854 to 0.02687, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0432 - root_mean_squared_error: 0.2078 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1639
# Epoch 56/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0595 - root_mean_squared_error: 0.2440
# Epoch 00056: val_loss did not improve from 0.02687
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0433 - root_mean_squared_error: 0.2082 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1700
# Epoch 57/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 00057: val_loss improved from 0.02687 to 0.02614, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0415 - root_mean_squared_error: 0.2038 - val_loss: 0.0261 - val_root_mean_squared_error: 0.1617
# Epoch 58/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0449 - root_mean_squared_error: 0.2119
# Epoch 00058: val_loss improved from 0.02614 to 0.02496, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0363 - root_mean_squared_error: 0.1907 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1580
# Epoch 59/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0342 - root_mean_squared_error: 0.1851
# Epoch 00059: val_loss improved from 0.02496 to 0.02496, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0353 - root_mean_squared_error: 0.1879 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1580
# Epoch 60/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0489 - root_mean_squared_error: 0.2210
# Epoch 00060: val_loss did not improve from 0.02496
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0374 - root_mean_squared_error: 0.1934 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1607
# Epoch 61/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0441 - root_mean_squared_error: 0.2099
# Epoch 00061: val_loss improved from 0.02496 to 0.02372, saving model to ../out/union/lstm/cp.ckpt
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0350 - root_mean_squared_error: 0.1872 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 62/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0423 - root_mean_squared_error: 0.2057
# Epoch 00062: val_loss did not improve from 0.02372
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0329 - root_mean_squared_error: 0.1814 - val_loss: 0.0257 - val_root_mean_squared_error: 0.1602
# Epoch 63/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0421 - root_mean_squared_error: 0.2051
# Epoch 00063: val_loss did not improve from 0.02372
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0347 - root_mean_squared_error: 0.1863 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1551
# Epoch 64/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0510 - root_mean_squared_error: 0.2259
# Epoch 00064: val_loss did not improve from 0.02372
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0363 - root_mean_squared_error: 0.1905 - val_loss: 0.0296 - val_root_mean_squared_error: 0.1721
# Epoch 65/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0560 - root_mean_squared_error: 0.2366
# Epoch 00065: val_loss did not improve from 0.02372
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0356 - root_mean_squared_error: 0.1886 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 66/1000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0388 - root_mean_squared_error: 0.1970
# Epoch 00066: val_loss did not improve from 0.02372
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0307 - root_mean_squared_error: 0.1753 - val_loss: 0.0267 - val_root_mean_squared_error: 0.1633
# Epoch 00066: early stopping
# /tmp/ipykernel_1112397/3499777157.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ".r" (-> color='r'). The keyword argument will take precedence.
#   plt.errorbar(df_SNe['zCMB'], df_SNe['MU'], yerr=df_SNe['MUERR'], fmt='.r', label=dataset+' Sample', color='r');
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 4, 1)]            0
#
#  lstm_8 (LSTM)               (None, 4, 100)            40800
#
#  dropout_8 (Dropout)         (None, 4, 100)            0
#
#  lstm_9 (LSTM)               (None, 4, 100)            80400
#
#  dropout_9 (Dropout)         (None, 4, 100)            0
#
#  dense_4 (Dense)             (None, 4, 1)              101
#
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 4, 1)]            0
#
#  lstm_10 (LSTM)              (None, 4, 100)            40800
#
#  dropout_10 (Dropout)        (None, 4, 100)            0
#
#  lstm_11 (LSTM)              (None, 4, 100)            80400
#
#  dropout_11 (Dropout)        (None, 4, 100)            0
#
#  dense_5 (Dense)             (None, 4, 1)              101
#
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________
# Requirement already satisfied: corner in /home/shreeprasad/.local/lib/python3.8/site-packages (2.2.1)
# Requirement already satisfied: matplotlib>=2.1 in /home/shreeprasad/.local/lib/python3.8/site-packages (from corner) (3.5.1)
# Requirement already satisfied: numpy>=1.17 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (1.22.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (3.0.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.1->corner) (7.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/shreeprasad/.local/lib/python3.8/site-packages (from matplotlib>=2.1->corner) (21.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.14.0)
# Requirement already up-to-date: emcee in /home/shreeprasad/.local/lib/python3.8/site-packages (3.1.2)
# Requirement already satisfied, skipping upgrade: numpy in /home/shreeprasad/.local/lib/python3.8/site-packages (from emcee) (1.22.3)
# /home/shreeprasad/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/shreeprasad/.local/lib/python3.8/site-packages/pandas/core/arraylike.py:397: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Requirement already satisfied: tabulate in /home/shreeprasad/.local/lib/python3.8/site-packages (0.8.9)
# ╒══════════════════════════════╤═════════╤═══════════╤════════════╤══════════╤═════════════╤═════════════════╕
# │                              │       a │     a_err │          b │    b_err │   sigma_int │   sigma_int_err │
# ╞══════════════════════════════╪═════════╪═══════════╪════════════╪══════════╪═════════════╪═════════════════╡
# │ ('E_peak-E_gamma', 'All-z')  │ 50.5446 │ 0.0708959 │  1.57872   │ 0.173163 │    0.284906 │       0.0818654 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-E_gamma', 'high-z') │ 50.3619 │ 0.158705  │  1.5708    │ 0.495007 │    0.452872 │       0.181846  │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-E_gamma', 'low-z')  │ 50.6746 │ 0.0761806 │  1.56087   │ 0.179003 │    0.212933 │       0.0846982 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-E_iso', 'All-z')    │ 52.5299 │ 0.0559033 │  1.3571    │ 0.127259 │    0.521696 │       0.0412885 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-E_iso', 'high-z')   │ 52.5119 │ 0.0668466 │  1.1299    │ 0.170112 │    0.472499 │       0.0494636 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-E_iso', 'low-z')    │ 52.5975 │ 0.101054  │  1.59661   │ 0.201134 │    0.594821 │       0.0784056 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-L', 'All-z')        │ 51.9451 │ 0.0516049 │  1.28139   │ 0.119663 │    0.496431 │       0.0403184 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-L', 'high-z')       │ 52.0029 │ 0.0587196 │  0.991556  │ 0.160268 │    0.398966 │       0.0473291 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('E_peak-L', 'low-z')        │ 51.9156 │ 0.0921356 │  1.45594   │ 0.184387 │    0.595548 │       0.0699303 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('T_RT-L', 'All-z')          │ 52.5069 │ 0.074831  │ -0.980112  │ 0.122578 │    0.464847 │       0.0464839 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('T_RT-L', 'high-z')         │ 52.3858 │ 0.0898712 │ -0.627184  │ 0.177343 │    0.430398 │       0.0646723 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('T_RT-L', 'low-z')          │ 52.7268 │ 0.130043  │ -1.32965   │ 0.18994  │    0.483778 │       0.0682108 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('T_lag-L', 'All-z')         │ 52.1412 │ 0.0619321 │ -0.649578  │ 0.101007 │    0.428554 │       0.0483432 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('T_lag-L', 'high-z')        │ 52.1848 │ 0.0780003 │ -0.505003  │ 0.133965 │    0.362697 │       0.0674037 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('T_lag-L', 'low-z')         │ 52.1375 │ 0.102731  │ -0.77588   │ 0.157291 │    0.510334 │       0.0842839 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('V-L', 'All-z')             │ 52.3278 │ 0.135959  │  0.324912  │ 0.150888 │    0.786619 │       0.065721  │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('V-L', 'high-z')            │ 52.5637 │ 0.24371   │  0.0960943 │ 0.226292 │    0.662973 │       0.0727405 │
# ├──────────────────────────────┼─────────┼───────────┼────────────┼──────────┼─────────────┼─────────────────┤
# │ ('V-L', 'low-z')             │ 52.1356 │ 0.248787  │  0.65318   │ 0.370128 │    0.920488 │       0.136127  │
# ╘══════════════════════════════╧═════════╧═══════════╧════════════╧══════════╧═════════════╧═════════════════╛
# Expected : 1.0253936755386988e+49
# Outcome : (6.232001714010707e+50, 5.734541386958471e+50)
# Requirement already satisfied: tqdm in /home/shreeprasad/.local/lib/python3.8/site-packages (4.64.0)
# 4597.358544821771
# /tmp/ipykernel_1112397/3141936610.py:2: RuntimeWarning: invalid value encountered in sqrt
#   return H_0 * np.sqrt((Omega_M * (1+z)**3 + 1 - Omega_M))
# /tmp/ipykernel_1112397/3141936610.py:10: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   r,e = scipy.integrate.quad(vfunc,0.1,z,args=(Omega_M))
# /home/shreeprasad/.local/lib/python3.8/site-packages/scipy/optimize/_minpack_py.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Omega_M 0.5141219610557101
#   0%|                                                  | 0/5000 [00:00<?, ?it/s]/home/shreeprasad/.local/lib/python3.8/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|███████████████████████████████████████| 5000/5000 [02:51<00:00, 29.11it/s]
# omega_M = 0.5017637285306227
# omega_M_err = 0.712271139907859
# omega_L = 0.4982362714693773
# omega_L_err = 0.712271139907859
