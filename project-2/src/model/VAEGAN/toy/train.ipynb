# %%
import os
import sys
from shutil import copyfile
import json
import numpy as np
from sklearn.model_selection import train_test_split 
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping

# add parent directory of project to system path, to access all the packages in project, sys.path.append appends are not permanent
sys.path.append(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('train.py')))))))

from src.data.toy_models.ParabolicModel import ParabolicModel
from src.data.toy_models.SineModel import SineModel

from src.model.VAEGAN.Encoder import Encoder 
from src.model.VAEGAN.Generator import Generator
from src.model.VAEGAN.Discriminator import Discriminator
from src.model.VAEGAN.UnsupervisedDiscriminator import UnsupervisedDiscriminator
from src.model.VAEGAN.SupervisedDiscriminator import SupervisedDiscriminator
from src.model.VAEGAN.VAEGAN import VAEGAN
from src.model.VAEGAN.toy.GANMonitor import GANMonitor

readlines = ""
with open('Params.json') as file:
    readlines = file.read() 

Params = json.loads(readlines) 
latent_dim = Params['latent_dim'] 
epochs = Params['epochs']
patience = Params['patience']
lr_gen = Params['lr_gen']
beta_1_gen = Params['beta_1_gen']
lr_disc = Params['lr_disc']
beta_1_disc= Params['beta_1_disc']
batch_size = Params['batch_size']
input_dim = Params['input_dim']
output_dim = Params['output_dim']
n_classes = Params['n_classes']
train_size = Params['train_size']
buffer_size = train_size 
outdir = Params['outdir'] 

if not os.path.isdir(outdir):
    os.makedirs(outdir)
if not os.path.isdir(os.path.join(outdir, 'fig')):
    os.mkdir(os.path.join(outdir, 'fig')) 
if not os.path.isdir(os.path.join(outdir, 'ckpt')):
    os.mkdir(os.path.join(outdir, 'ckpt'))
if not os.path.isdir(os.path.join(outdir, 'log')):
    os.mkdir(os.path.join(outdir, 'log'))

copyfile('Params.json',os.path.join(outdir, 'Params.json'))

def generate_real_samples(train_size, z, input_dim):
    half_train_size = int(train_size/2) 
    parabolicModelObj = ParabolicModel()
    x1 = np.zeros([half_train_size, input_dim], dtype='float32')
    for i in range(half_train_size):
        x1[i] = parabolicModelObj.sample(z)
    y1 = np.zeros(half_train_size)
    sineModelObj = SineModel()
    x2 = np.zeros([half_train_size, input_dim], dtype='float32')
    for i in range(half_train_size):
        x2[i] = sineModelObj.sample(z)
    y2 = np.ones(half_train_size)
    x_real = np.concatenate([x1, x2])
    y_real = np.concatenate([y1, y2])
    return x_real, y_real


z = np.genfromtxt('../../../data/toy_models/z.csv')
z_obs = np.genfromtxt('../../../data/toy_models/z_obs.csv')
x_real, y_real = generate_real_samples(train_size, z, output_dim) 
prng = np.random.RandomState(123)
idx = prng.randint(0, output_dim, input_dim)
x_real_580 = x_real[:,idx]
y_real = y_real[:, np.newaxis]

# split into test, validation, and training sets
x_train_580, x_test_580, x_train, x_test, y_train, y_test = train_test_split(x_real_580, x_real, y_real, test_size=0.2)
x_train_580, x_val_580, x_train, x_val, y_train, y_val = train_test_split(x_train_580, x_train, y_train, test_size=0.2)

train_dataset = ( 
    tf.data.Dataset
        .from_tensor_slices((x_train_580, x_train, y_train))
        .shuffle(buffer_size, reshuffle_each_iteration=True)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset
        .from_tensor_slices((x_val_580, x_val, y_val))
        .shuffle(buffer_size)
        .batch(batch_size)
)

test_dataset = (
    tf.data.Dataset
        .from_tensor_slices((x_test_580, x_test, y_test))
        .shuffle(buffer_size)
        .batch(batch_size)
)

encoder = Encoder(input_dim, latent_dim)
generator = Generator(latent_dim)
discriminator = Discriminator(output_dim, n_classes)
sup_discriminator = SupervisedDiscriminator(discriminator)
unsup_discriminator = UnsupervisedDiscriminator(discriminator)

vaegan = VAEGAN(latent_dim, encoder, generator, discriminator, sup_discriminator, unsup_discriminator, z)
vaegan.compile(
    tf.keras.optimizers.Adam(learning_rate=lr_gen, beta_1=beta_1_gen),
    tf.keras.optimizers.Adam(learning_rate=lr_disc, beta_1=beta_1_disc), 
    tf.keras.optimizers.Adam(learning_rate=lr_disc, beta_1=beta_1_disc),
    tf.keras.optimizers.Adam(learning_rate=lr_gen, beta_1=beta_1_gen),
    tf.keras.losses.BinaryCrossentropy(from_logits=False),
    tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)
)

vaegan_checkpoint_path = os.path.join(outdir,"ckpt/vaegan.ckpt")
#g_checkpoint_path = os.path.join(outdir,"ckpt/generator.ckpt")
#d_checkpoint_path = os.path.join(outdir,"ckpt/discriminator.ckpt")

csvlogger_path = os.path.join(outdir,"log/log.txt")

callbacks = [
    #ModelCheckpoint(checkpoint_path, monitor='val_s_loss', save_best_only=True, save_weights_only=True, verbose=1),
    #EarlyStopping(monitor='val_s_loss', patience=patience, verbose=1),
    CSVLogger(csvlogger_path, separator=',', append=True),
    GANMonitor()
]

history = vaegan.fit(
    train_dataset, 
    epochs=epochs, 
    validation_data = val_dataset,
    callbacks = callbacks
)

#generator.save_weights(g_checkpoint_path)
#discriminator.save_weights(d_checkpoint_path)
vaegan.save_weights(vaegan_checkpoint_path)

# load the best model
vaegan.load_weights(vaegan_checkpoint_path)

# number of epochs, early stopped or not
epochs = len(history.history['s_loss'])

plt.figure()
plt.plot(history.history['e_loss'], '-', label='e_loss')
plt.plot(history.history['val_e_loss'], '--', label='val_e_loss')
plt.plot(history.history['g_loss'], '-', label='g_loss')
plt.plot(history.history['val_g_loss'], '--', label='val_g_loss')
plt.plot(history.history['u_loss'], '-', label='u_loss')
plt.plot(history.history['val_u_loss'], '--', label='val_u_loss')
plt.plot(history.history['s_loss'], label='s_loss')
plt.plot(history.history['val_s_loss'], label='val_s_loss')
plt.title('VAE loss curve')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.savefig(os.path.join(outdir,'fig/loss_curve.png'))
plt.draw()
plt.pause(0.001)
#plt.show()

plt.figure()
plt.plot(history.history['s_acc'], label='s_acc')
plt.plot(history.history['val_s_acc'], label='val_s_acc')
plt.plot(history.history['u_acc'], label='u_acc')
plt.plot(history.history['val_u_acc'], label='val_u_acc')
plt.title('accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.savefig(os.path.join(outdir,'fig/accuracy.png'))
plt.draw()
plt.pause(0.001)
#plt.show()


x = vaegan.out_with_enc(x_test_580[0].reshape(-1,580))
# Out:
# 2022-06-11 10:31:51.736327: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2022-06-11 10:31:51.736380: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: spk
# 2022-06-11 10:31:51.736390: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: spk
# 2022-06-11 10:31:51.736534: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.129.6
# 2022-06-11 10:31:51.736567: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 470.103.1
# 2022-06-11 10:31:51.736576: E tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 470.103.1 does not match DSO version 470.129.6 -- cannot find working devices in this configuration
# 2022-06-11 10:31:51.736968: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# (None, 1) (None, 2)
# (None, 1) (None, 2)
# 80/80 [==============================] - ETA: 0s - e_loss: 0.5579 - s_loss: 0.7063 - u_loss: 0.4120 - g_loss: 40.9905 - s_acc: 0.5203 - u_acc: 0.6500
# tf.Tensor([[0.48422265 0.51577735]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 13s 95ms/step - e_loss: 0.5579 - s_loss: 0.7063 - u_loss: 0.4120 - g_loss: 40.9905 - s_acc: 0.5203 - u_acc: 0.6500 - val_e_loss: 40.7202 - val_s_loss: 0.7156 - val_u_loss: 0.1069 - val_g_loss: 75.9625 - val_s_acc: 0.4625 - val_u_acc: 1.0000
# Epoch 2/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.5474 - s_loss: 0.5841 - u_loss: -0.0574 - g_loss: 189.6513 - s_acc: 0.6891 - u_acc: 1.0000
# tf.Tensor([[0.48560077 0.51439923]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 76ms/step - e_loss: 0.5474 - s_loss: 0.5841 - u_loss: -0.0574 - g_loss: 189.6513 - s_acc: 0.6891 - u_acc: 1.0000 - val_e_loss: 413.5453 - val_s_loss: 0.5446 - val_u_loss: -0.1214 - val_g_loss: 266.6704 - val_s_acc: 0.5750 - val_u_acc: 1.0000
# Epoch 3/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.5443 - s_loss: 0.4538 - u_loss: -0.1337 - g_loss: 259.2957 - s_acc: 0.8719 - u_acc: 1.0000
# tf.Tensor([[0.46977276 0.53022724]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.5443 - s_loss: 0.4538 - u_loss: -0.1337 - g_loss: 259.2957 - s_acc: 0.8719 - u_acc: 1.0000 - val_e_loss: 433.2665 - val_s_loss: 0.3864 - val_u_loss: -0.1281 - val_g_loss: 267.0593 - val_s_acc: 0.9062 - val_u_acc: 1.0000
# Epoch 4/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.5381 - s_loss: 0.3494 - u_loss: -0.1237 - g_loss: 264.7857 - s_acc: 0.9266 - u_acc: 1.0000
# tf.Tensor([[0.3988798 0.6011202]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.5381 - s_loss: 0.3494 - u_loss: -0.1237 - g_loss: 264.7857 - s_acc: 0.9266 - u_acc: 1.0000 - val_e_loss: 419.8464 - val_s_loss: 0.2711 - val_u_loss: -0.1289 - val_g_loss: 262.6994 - val_s_acc: 0.9937 - val_u_acc: 1.0000
# Epoch 5/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.5334 - s_loss: 0.2601 - u_loss: -0.1326 - g_loss: 265.5579 - s_acc: 0.9609 - u_acc: 1.0000
# tf.Tensor([[0.4219692 0.5780308]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.5334 - s_loss: 0.2601 - u_loss: -0.1326 - g_loss: 265.5579 - s_acc: 0.9609 - u_acc: 1.0000 - val_e_loss: 447.5795 - val_s_loss: 0.2656 - val_u_loss: -0.1168 - val_g_loss: 267.7534 - val_s_acc: 0.9438 - val_u_acc: 1.0000
# Epoch 6/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.5304 - s_loss: 0.1883 - u_loss: -0.1308 - g_loss: 268.8452 - s_acc: 0.9828 - u_acc: 1.0000
# tf.Tensor([[0.27463263 0.72536737]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.
], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.2365 - s_loss: 0.0119 - u_loss: 0.4326 - g_loss: 21.8511 - s_acc: 1.0000 - u_acc: 0.7445 - val_e_loss: 35.4936 - val_s_loss: 0.0104 - val_u_loss: 0.5111 - val_g_loss: 2.3561 - val_s_acc: 1.0000 - val_u_acc: 0.6781
# Epoch 49/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.2381 - s_loss: 0.0535 - u_loss: 0.7878 - g_loss: -1.4143 - s_acc: 0.9781 - u_acc: 0.7312
# tf.Tensor([[1.3543914e-04 9.9986458e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.2381 - s_loss: 0.0535 - u_loss: 0.7878 - g_loss: -1.4143 - s_acc: 0.9781 - u_acc: 0.7312 - val_e_loss: 54.7768 - val_s_loss: 0.0162 - val_u_loss: 0.3998 - val_g_loss: 19.4687 - val_s_acc: 1.0000 - val_u_acc: 0.7563
# Epoch 50/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.2445 - s_loss: 0.0151 - u_loss: 0.6468 - g_loss: 8.4615 - s_acc: 1.0000 - u_acc: 0.6844
# tf.Tensor([[1.8198376e-04 9.9981803e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.2445 - s_loss: 0.0151 - u_loss: 0.6468 - g_loss: 8.4615 - s_acc: 1.0000 - u_acc: 0.6844 - val_e_loss: 40.9359 - val_s_loss: 0.0214 - val_u_loss: 1.1843 - val_g_loss: 19.1690 - val_s_acc: 1.0000 - val_u_acc: 0.3313
# Epoch 51/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.2340 - s_loss: 0.0166 - u_loss: 0.9847 - g_loss: -1.0908 - s_acc: 1.0000 - u_acc: 0.6281
# tf.Tensor([[0.00593351 0.9940665 ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 78ms/step - e_loss: 0.2340 - s_loss: 0.0166 - u_loss: 0.9847 - g_loss: -1.0908 - s_acc: 1.0000 - u_acc: 0.6281 - val_e_loss: 25.5288 - val_s_loss: 0.0127 - val_u_loss: 1.0102 - val_g_loss: 15.3559 - val_s_acc: 1.0000 - val_u_acc: 0.4437
# Epoch 52/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.2272 - s_loss: 0.0138 - u_loss: 0.5335 - g_loss: 5.5476 - s_acc: 1.0000 - u_acc: 0.7188
# tf.Tensor([[0.03679147 0.9632085 ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.2272 - s_loss: 0.0138 - u_loss: 0.5335 - g_loss: 5.5476 - s_acc: 1.0000 - u_acc: 0.7188 - val_e_loss: 37.5241 - val_s_loss: 0.0148 - val_u_loss: 0.2648 - val_g_loss: 22.9555 - val_s_acc: 1.0000 - val_u_acc: 0.8438
# Epoch 53/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.2214 - s_loss: 0.0139 - u_loss: 0.4367 - g_loss: 3.2039 - s_acc: 1.0000 - u_acc: 0.7469
# tf.Tensor([[0.01413425 0.9858657 ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.2214 - s_loss: 0.0139 - u_loss: 0.4367 - g_loss: 3.2039 - s_acc: 1.0000 - u_acc: 0.7469 - val_e_loss: 19.4061 - val_s_loss: 0.0384 - val_u_loss: 0.5488 - val_g_loss: -7.8581 - val_s_acc: 1.0000 - val_u_acc: 0.7312
# Epoch 54/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.2175 - s_loss: 0.0280 - u_loss: 0.4730 - g_loss: -12.8310 - s_acc: 1.0000 - u_acc: 0.7086
# tf.Tensor([[0.00411592 0.995884  ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.
100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.1035 - s_loss: 0.0068 - u_loss: -0.0143 - g_loss: 83.6389 - s_acc: 1.0000 - u_acc: 0.9984
# tf.Tensor([[6.2998277e-16 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.1035 - s_loss: 0.0068 - u_loss: -0.0143 - g_loss: 83.6389 - s_acc: 1.0000 - u_acc: 0.9984 - val_e_loss: 693.8243 - val_s_loss: 0.0082 - val_u_loss: -0.0127 - val_g_loss: 88.1162 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 82/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0972 - s_loss: 0.0065 - u_loss: 0.0052 - g_loss: 78.4367 - s_acc: 1.0000 - u_acc: 0.9984
# tf.Tensor([[6.759935e-10 1.000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 76ms/step - e_loss: 0.0972 - s_loss: 0.0065 - u_loss: 0.0052 - g_loss: 78.4367 - s_acc: 1.0000 - u_acc: 0.9984 - val_e_loss: 469.5169 - val_s_loss: 0.0071 - val_u_loss: 0.0170 - val_g_loss: 85.9675 - val_s_acc: 1.0000 - val_u_acc: 0.9937
# Epoch 83/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0888 - s_loss: 0.0063 - u_loss: 0.0857 - g_loss: 68.3827 - s_acc: 1.0000 - u_acc: 0.9617
# tf.Tensor([[3.2294018e-05 9.9996769e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 76ms/step - e_loss: 0.0888 - s_loss: 0.0063 - u_loss: 0.0857 - g_loss: 68.3827 - s_acc: 1.0000 - u_acc: 0.9617 - val_e_loss: 155.0663 - val_s_loss: 0.0099 - val_u_loss: 0.4036 - val_g_loss: 45.2270 - val_s_acc: 1.0000 - val_u_acc: 0.7312
# Epoch 84/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0734 - s_loss: 0.0076 - u_loss: 0.4725 - g_loss: 23.6168 - s_acc: 1.0000 - u_acc: 0.6875
# tf.Tensor([[1.5950221e-06 9.9999845e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 76ms/step - e_loss: 0.0734 - s_loss: 0.0076 - u_loss: 0.4725 - g_loss: 23.6168 - s_acc: 1.0000 - u_acc: 0.6875 - val_e_loss: 114.8622 - val_s_loss: 0.0067 - val_u_loss: 0.4143 - val_g_loss: 11.3465 - val_s_acc: 1.0000 - val_u_acc: 0.7688
# Epoch 85/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0833 - s_loss: 0.0070 - u_loss: 0.0665 - g_loss: 73.8510 - s_acc: 1.0000 - u_acc: 0.9516
# tf.Tensor([[1.7586627e-04 9.9982411e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0833 - s_loss: 0.0070 - u_loss: 0.0665 - g_loss: 73.8510 - s_acc: 1.0000 - u_acc: 0.9516 - val_e_loss: 73.9868 - val_s_loss: 0.0065 - val_u_loss: 0.5456 - val_g_loss: 21.8623 - val_s_acc: 1.0000 - val_u_acc: 0.6187
# Epoch 86/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0728 - s_loss: 0.0086 - u_loss: 0.5175 - g_loss: 31.8828 - s_acc: 1.0000 - u_acc: 0.6867
# tf.Tensor([[4.2705965e-19 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 76ms/step - e_loss: 0.0728 - s_loss: 0.0086 - u_loss: 0.5175 - g_loss: 31.8828 - s_acc: 1.0000 - u_acc: 0.6867 - val_e_loss: 1830.6643 - val_s_loss: 0.0161 - val_u_loss: -0.0751 - val_g_loss: 187.5488 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 87/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.1232 - s_loss: 0.0072 - u_loss: -0.1147 - g_loss: 219.7409 - s_acc: 1.0000 - u_acc: 1.0000
# tf.Tensor([[6.677583e-26 1.000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.1232 - s_loss: 0.0072 - u_loss: -0.1147 - g_loss: 219.7409 - s_acc: 1.0000 - u_acc: 1.0000 - val_e_loss: 2281.7529 - val_s_loss: 0.0071 - val_u_loss: -0.1000 - val_g_loss: 230.3711 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 88/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.1156 - s_loss: 0.0053 - u_loss: -0.0960 - g_loss: 213.0316 - s_acc: 1.0000 - u_acc: 1.0000
# tf.Tensor([[1.4199809e-22 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.1156 - s_loss: 0.0053 - u_loss: -0.0960 - g_loss: 213.0316 - s_acc: 1.0000 - u_acc: 1.0000 - val_e_loss: 1789.2028 - val_s_loss: 0.0062 - val_u_loss: -0.0824 - val_g_loss: 214.6581 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 89/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.1065 - s_loss: 0.0046 - u_loss: -0.0981 - g_loss: 193.7753 - s_acc: 1.0000 - u_acc: 1.0000
# tf.Tensor([[8.864749e-16 1.000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 78ms/step - e_loss: 0.1065 - s_loss: 0.0046 - u_loss: -0.0981 - g_loss: 193.7753 - s_acc: 1.0000 - u_acc: 1.0000 - val_e_loss: 1447.1979 - val_s_loss: 0.0051 - val_u_loss: -0.0840 - val_g_loss: 194.2190 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 90/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0951 - s_loss: 0.0040 - u_loss: -0.0750 - g_loss: 168.0127 - s_acc: 1.0000 - u_acc: 1.0000
# tf.Tensor([[4.8744337e-14 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0951 - s_loss: 0.0040 - u_loss: -0.0750 - g_loss: 168.0127 - s_acc: 1.0000 - u_acc: 1.0000 - val_e_loss: 1003.4616 - val_s_loss: 0.0045 - val_u_loss: -0.0842 - val_g_loss: 162.1223 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 91/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0892 - s_loss: 0.0037 - u_loss: -0.0573 - g_loss: 137.7258 - s_acc: 1.0000 - u_acc: 1.0000
# tf.Tensor([[4.2156803e-10 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0892 - s_loss: 0.0037 - u_loss: -0.0573 - g_loss: 137.7258 - s_acc: 1.0000 - u_acc: 1.0000 - val_e_loss: 766.6389 - val_s_loss: 0.0044 - val_u_loss: -0.0555 - val_g_loss: 132.6679 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 92/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0796 - s_loss: 0.0039 - u_loss: -0.0391 - g_loss: 112.2753 - s_acc: 1.0000 - u_acc: 0.9992
# tf.Tensor([[2.2536202e-08 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0796 - s_loss: 0.0039 - u_loss: -0.0391 - g_loss: 112.2753 - s_acc: 1.0000 - u_acc: 0.9992 - val_e_loss: 505.3813 - val_s_loss: 0.0055 - val_u_loss: -0.0353 - val_g_loss: 113.6553 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 93/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0744 - s_loss: 0.0045 - u_loss: -0.0018 - g_loss: 94.6386 - s_acc: 1.0000 - u_acc: 0.9992
# tf.Tensor([[6.1136116e-06 9.9999392e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0744 - s_loss: 0.0045 - u_loss: -0.0018 - g_loss: 94.6386 - s_acc: 1.0000 - u_acc: 0.9992 - val_e_loss: 327.6501 - val_s_loss: 0.0080 - val_u_loss: 0.0112 - val_g_loss: 100.4619 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# Epoch 94/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0622 - s_loss: 0.0059 - u_loss: 0.0809 - g_loss: 79.5773 - s_acc: 1.0000 - u_acc: 0.9703
# tf.Tensor([[4.1105122e-05 9.9995887e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0622 - s_loss: 0.0059 - u_loss: 0.0809 - g_loss: 79.5773 - s_acc: 1.0000 - u_acc: 0.9703 - val_e_loss: 209.5089 - val_s_loss: 0.0064 - val_u_loss: 0.0952 - val_g_loss: 82.4158 - val_s_acc: 1.0000 - val_u_acc: 0.9719
# Epoch 95/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0582 - s_loss: 0.0080 - u_loss: 0.3839 - g_loss: 39.0595 - s_acc: 1.0000 - u_acc: 0.7656
# tf.Tensor([[0.00763617 0.9923638 ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0582 - s_loss: 0.0080 - u_loss: 0.3839 - g_loss: 39.0595 - s_acc: 1.0000 - u_acc: 0.7656 - val_e_loss: 80.6280 - val_s_loss: 0.0061 - val_u_loss: 0.4400 - val_g_loss: 31.6136 - val_s_acc: 1.0000 - val_u_acc: 0.7063
# Epoch 96/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0518 - s_loss: 0.1071 - u_loss: 1.9319 - g_loss: -48.9150 - s_acc: 0.9391 - u_acc: 0.5648
# tf.Tensor([[0.99188656 0.00811338]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([0], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0518 - s_loss: 0.1071 - u_loss: 1.9319 - g_loss: -48.9150 - s_acc: 0.9391 - u_acc: 0.5648 - val_e_loss: 113.3756 - val_s_loss: 0.0121 - val_u_loss: 4.0370 - val_g_loss: 34.5899 - val_s_acc: 1.0000 - val_u_acc: 0.2781
# Epoch 97/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0438 - s_loss: 0.5440 - u_loss: 2.5443 - g_loss: -79.1073 - s_acc: 0.8109 - u_acc: 0.4852
# tf.Tensor([[0.00814279 0.9918573 ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0438 - s_loss: 0.5440 - u_loss: 2.5443 - g_loss: -79.1073 - s_acc: 0.8109 - u_acc: 0.4852 - val_e_loss: 20.1394 - val_s_loss: 0.0584 - val_u_loss: 0.6554 - val_g_loss: -47.8538 - val_s_acc: 1.0000 - val_u_acc: 0.7219
# Epoch 98/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0432 - s_loss: 0.0573 - u_loss: 0.3910 - g_loss: -22.9566 - s_acc: 0.9844 - u_acc: 0.8336
# tf.Tensor([[1.5754664e-04 9.9984241e-01]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0432 - s_loss: 0.0573 - u_loss: 0.3910 - g_loss: -22.9566 - s_acc: 0.9844 - u_acc: 0.8336 - val_e_loss: 25.3899 - val_s_loss: 0.0035 - val_u_loss: 0.2050 - val_g_loss: -1.6912 - val_s_acc: 1.0000 - val_u_acc: 0.9812
# Epoch 99/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0431 - s_loss: 0.0031 - u_loss: 0.1975 - g_loss: -6.5927 - s_acc: 1.0000 - u_acc: 0.9883
# tf.Tensor([[0.00840893 0.9915911 ]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 76ms/step - e_loss: 0.0431 - s_loss: 0.0031 - u_loss: 0.1975 - g_loss: -6.5927 - s_acc: 1.0000 - u_acc: 0.9883 - val_e_loss: 32.5827 - val_s_loss: 0.0029 - val_u_loss: 0.1922 - val_g_loss: 3.2980 - val_s_acc: 1.0000 - val_u_acc: 0.9969
# Epoch 100/100
# 80/80 [==============================] - ETA: 0s - e_loss: 0.0451 - s_loss: 0.0025 - u_loss: 0.1840 - g_loss: -5.1475 - s_acc: 1.0000 - u_acc: 0.9844
# tf.Tensor([[2.2656874e-16 1.0000000e+00]], shape=(1, 2), dtype=float32)
# Class :  tf.Tensor([1], shape=(1,), dtype=int64)
# 80/80 [==============================] - 6s 75ms/step - e_loss: 0.0451 - s_loss: 0.0025 - u_loss: 0.1840 - g_loss: -5.1475 - s_acc: 1.0000 - u_acc: 0.9844 - val_e_loss: 881.5839 - val_s_loss: 0.0028 - val_u_loss: 0.0450 - val_g_loss: 21.4213 - val_s_acc: 1.0000 - val_u_acc: 1.0000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 185>()
#     181 plt.pause(0.001)
#     182 #plt.show()
# --> 185 x = vaegan.out_with_enc(x_test_580[0].reshape(-1,580))
#
# AttributeError: 'VAEGAN' object has no attribute 'out_with_enc'
